# %% [markdown]
# <a href="https://colab.research.google.com/github/aakhterov/Python_practice/blob/master/SQL_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# enable using commands %sql and %%sql
# %load_ext sql

# %%
def prepare_data_from_csv(path_to_csv: str) -> str:
  '''
  format content from csv file for using in 'insert' SQL queries
  '''
  df = pd.read_csv(path_to_csv)
  return ','.join([str(tuple(row)) for row in df.values.tolist()])

# %%
# connect to a database sqltraining.sqlite
# %sql sqlite:////content/drive/MyDrive/sqltraining.sqlite

# %% [markdown]
# # Task #1 Duplicate Transactions

# %% [markdown]
# **Problem:**
#
# The duplicate_transactions table contains transaction_id, timestamp, price and department.
#
# Address these four questions:
#
# 1. How many duplicate records are there? For instance, if Row 1, and Row 2 and Row 3 contain the same values, then there are two duplicate records.
#
# 2. How many unique records have duplications?
#
# 3. Remove duplicate records, only preserving the unique records.
#
# 4. Which department has the highest duplicate records? Return the department name and count of duplicate records. Assume the possibility that multiple departments
# could have the same highest count.

# %% [markdown]
# ## 1.1. Creating tables and inserting values

# %%
# %sql drop table duplicate_transactions
# Out:
#  * sqlite:////content/drive/MyDrive/sqltraining.sqlite
# Done.
# []

# %%
# %%sql
# CREATE TABLE duplicate_transactions (
# transaction_id VARCHAR,
# timestamp INTEGER,
# price INTEGER,
# department VARCHAR);
# Out:
#  * sqlite:////content/drive/MyDrive/sqltraining.sqlite
# Done.
# []

# %%
data = prepare_data_from_csv('/content/drive/MyDrive/Colab Notebooks/Data/SQL_training/duplicate_transactions/duplicate_transactions.csv')
data[:100]
# Out:
# "('qsllwzfgsu', 815725, 67, 'Movies'),('ldfdvwgsxa', 863206, 18, 'Groceries'),('glvkzgxobb', 846203, "

# %%
# %%sql insert into duplicate_transactions values {data}
# Out:
#  * sqlite:////content/drive/MyDrive/sqltraining.sqlite
# 580 rows affected.
# []

# %% [markdown]
# ## 1.2. Look at the tables

# %%
# %sql select * from duplicate_transactions limit 1, 5
# Out:
#  * sqlite:////content/drive/MyDrive/sqltraining.sqlite
# Done.
# [('ldfdvwgsxa', 863206, 18, 'Groceries'),
#  ('glvkzgxobb', 846203, 58, 'Computer'),
#  ('gnrowryred', 865632, 48, 'Computer'),
#  ('wulekumebr', 871200, 47, 'Music'),
#  ('mudonayuog', 865647, 26, 'Groceries')]

# %% [markdown]
# ## 1.3. Solution

# %% [markdown]
# 1. How many duplicate records are there? For instance, if Row 1, and Row 2 and Row 3 contain the same values, then there are two duplicate records.

# %%
# %%sql
# select sum(c) as duplicates_count from
# (
#   select count(*)-1 as c
#   from duplicate_transactions
#   group by transaction_id, timestamp, price, department
#   having count(*) > 1
# )
# Out:
#  * sqlite:////content/drive/MyDrive/sqltraining.sqlite
# Done.
# [(80,)]

# %% [markdown]
# 2. How many unique records have duplications?

# %%
# %%sql
# select count(transaction_id) as records_have_duplications from
# (
#   select transaction_id
#   from duplicate_transactions
#   group by transaction_id, timestamp, price, department
#   having count(*) > 1
# )
# Out:
#  * sqlite:////content/drive/MyDrive/sqltraining.sqlite
# Done.
# [(47,)]

# %% [markdown]
# 3. Remove duplicate records, only preserving the unique records.

# %%
# %%sql
# select distinct *
# from duplicate_transactions
# Out:
#  * sqlite:////content/drive/MyDrive/sqltraining.sqlite
# Done.
# [('qsllwzfgsu', 815725, 67, 'Movies'),
#  ('ldfdvwgsxa', 863206, 18, 'Groceries'),
#  ('glvkzgxobb', 846203, 58, 'Computer'),
#  ('gnrowryred', 865632, 48, 'Computer'),
#  ('wulekumebr', 871200, 47, 'Music'),
#  ('mudonayuog', 865647, 26, 'Groceries'),
#  ('xycfertiwm', 835662, 37, 'Music'),
#  ('jezmgvkcfh', 883012, 50, 'Groceries'),
#  ('wldyhjgwbm', 826626, 85, 'Books'),
#  ('jwqmpbxuhg', 830255, 62, 'Music'),
#  ('wwbvovukzk', 883079, 93, 'Movies'),
#  ('yqrliffwln', 817766, 98, 'MISC'),
#  ('dbqbjeupcc', 811894, 95, 'Groceries'),
#  ('ugbdqvafok', 867874, 98, 'Movies'),
#  ('drvvfsukzz', 820355, 70, 'Music'),
#  ('dxzwnbyaew', 866978, 59, 'Books'),
#  ('hvogwqqomb', 879565, 19, 'Movies'),
#  ('tjtxjmckvb', 815631, 28, 'MISC'),
#  ('umrbdqjdim', 857324, 31, 'Movies'),
#  ('qefbrneymv', 824134, 27, 'Music'),
#  ('xaakybfcib', 803316, 76, 'Computer'),
#  ('xzjzlwrsgr', 808747, 59, 'MISC'),
#  ('jukrlmgcqy', 874423, 26, 'Books'),
#  ('qldqkrteql', 842964, 57, 'Computer'),
#  ('xparscjhpi', 870162, 82, 'Computer'),
#  ('hqaobxlrcj', 879923, 45, 'MISC'),
#  ('drjbyjkdth', 889833, 49, 'Music'),
#  ('undueijvcw', 826587, 50, 'Groceries'),
#  ('rgxlofaqre', 864579, 12, 'MISC'),
#  ('kebwzkicnk', 868057, 4, 'Groceries'),
#  ('fbiyiqswlq', 829427, 95, 'Computer'),
#  ('hltvhdriez', 817495, 15, 'Groceries'),
#  ('pilltrcrvy', 860281, 71, 'Movies'),
#  ('zxmnjtsmde', 898742, 28, 'Computer'),
#  ('oigvwtizpt', 812221, 75, 'Groceries'),
#  ('swfsnyzjwq', 885620, 66, 'MISC'),
#  ('ktbcczacxf', 845072, 6, 'Music'),
#  ('kpaqbztsrx', 809325, 87, 'Groceries'),
#  ('ewylqvtfyz', 814632, 26, 'MISC'),
#  ('rpieawrkph', 863232, 36, 'MISC'),
#  ('agnrqrljkg', 897665, 84, 'Movies'),
#  ('nmciorzbms', 897182, 8, 'MISC'),
#  ('hpeoeeviql', 826684, 66, 'Movies'),
#  ('rchjnivyte', 837630, 77, 'Groceries'),
#  ('pemsenbljt', 898092, 52, 'Music'),
#  ('xypsbchyiw', 863430, 14, 'Movies'),
#  ('swlidvqesv', 821868, 64, 'Movies'),
#  ('agbvzfklnl', 889719, 97, 'Computer'),
#  ('ejkcdsyzym', 849576, 89, 'Movies'),
#  ('tgaocksyrg', 827386, 64, 'Books'),
#  ('bvelpfvilq', 824045, 78, 'Music'),
#  ('xekhzndehd', 848334, 7, 'Computer'),
#  ('kkxzakhyxw', 821726, 71, 'Music'),
#  ('skixzhplft', 812151, 75, 'Movies'),
#  ('dvavdxidmh', 841420, 26, 'Books'),
#  ('dxucernfsn', 891633, 8, 'MISC'),
#  ('rgsvvbypgv', 834220, 2, 'Computer'),
#  ('cvmmlqvyqy', 801230, 57, 'Computer'),
#  ('tbenkxnujj', 818947, 18, 'Music'),
#  ('iwmlkvypcs', 819671, 70, 'Computer'),
#  ('evoykxmjts', 810802, 3, 'Books'),
#  ('hmjbcypurr', 830510, 46, 'Computer'),
#  ('laubhzfgzx', 874659, 19, 'Groceries'),
#  ('mvltzfqbyw', 890798, 55, 'Computer'),
#  ('kdswoyzbrp', 880849, 63, 'Groceries'),
#  ('bxekbvciuk', 850827, 27, 'Movies'),
#  ('cigehqrtxp', 898296, 76, 'Books'),
#  ('tsatbicgde', 847738, 59, 'Groceries'),
#  ('yshsopacui', 890519, 26, 'Groceries'),
#  ('mguozcmfbf', 882361, 4, 'Groceries'),
#  ('osqdqueigi', 810958, 86, 'Groceries'),
#  ('uwofloslim', 852726, 49, 'Music'),
#  ('pnwbjzrsdj', 815319, 88, 'Movies'),
#  ('rxkmhznvdj', 869957, 57, 'Movies'),
#  ('mibmtuciiy', 814985, 67, 'MISC'),
#  ('vjkcjxfwlk', 870725, 10, 'Groceries'),
#  ('bhhrectdoq', 871196, 67, 'Books'),
#  ('usqrphzrwv', 842724, 4, 'Music'),
#  ('ekivpkqfgt', 848899, 24, 'Groceries'),
#  ('atvdidvfba', 830391, 35, 'MISC'),
#  ('ndtpslhnub', 837719, 86, 'Computer'),
#  ('nqotepzviu', 880273, 59, 'Books'),
#  ('jpkhjyhext', 838189, 11, 'Music'),
#  ('jcyhfmrypj', 817141, 97, 'Computer'),
#  ('uldhllbokr', 853603, 68, 'Groceries'),
#  ('pjmdxfsuty', 868929, 8, 'Groceries'),
#  ('jcihoegkiu', 803026, 93, 'MISC'),
#  ('pwemvcsjaf', 826761, 41, 'Computer'),
#  ('ndspaoypzw', 864836, 88, 'Music'),
#  ('rgqrmzmjec', 872498, 37, 'Movies'),
#  ('gulfvvgakm', 800604, 84, 'Computer'),
#  ('xcjohwzcfq', 811239, 62, 'Music'),
#  ('rtojxxxaqv', 878837, 15, 'Movies'),
#  ('umltmcjtjt', 888693, 81, 'Music'),
#  ('qwojgxmwnu', 855534, 25, 'Computer'),
#  ('uzdbzjiqyr', 868048, 85, 'Groceries'),
#  ('ewdesbgicr', 872431, 91, 'MISC'),
#  ('qmarvyfxpd', 845205, 33, 'Computer'),
#  ('ggrpuyraxb', 879714, 83, 'Books'),
#  ('wncbljqcga', 863847, 36, 'Books'),
#  ('ncexdqkyeu', 808102, 2, 'Music'),
#  ('qskktjephu', 854161, 46, 'MISC'),
#  ('rgoyvrnvni', 808522, 1, 'Groceries'),
#  ('ofipkcrnmn', 899185, 84, 'MISC'),
#  ('miqcsuuebv', 838739, 79, 'MISC'),
#  ('jlwxfosisg', 889107, 38, 'Computer'),
#  ('mqjagfgvxb', 808325, 82, 'Groceries'),
#  ('edxeitjnsi', 841569, 94, 'Books'),
#  ('bzzixfktmi', 880465, 22, 'Music'),
#  ('icwewjkzii', 803358, 56, 'Music'),
#  ('limbuzwhqm', 860574, 13, 'Books'),
#  ('vdqgtzozug', 889488, 93, 'Books'),
#  ('zhenbhjuub', 899847, 38, 'Computer'),
#  ('zubnrurxhv', 845696, 97, 'Books'),
#  ('hvzmnaddnf', 881894, 38, 'MISC'),
#  ('qltpthbccg', 892686, 62, 'Movies'),
#  ('ovcmpossap', 841321, 82, 'MISC'),
#  ('svzbsdyjpz', 843230, 20, 'Books'),
#  ('tsvswxzddm', 884998, 91, 'MISC'),
#  ('lvpwfbntlf', 818673, 79, 'Music'),
#  ('hyvsnbfbmr', 831283, 98, 'Groceries'),
#  ('gtzqwnlefe', 893312, 78, 'MISC'),
#  ('tejwkpocwt', 856945, 53, 'Groceries'),
#  ('fegscwjudz', 863458, 97, 'Books'),
#  ('aqjjttfmnj', 813147, 91, 'Music'),
#  ('poxwtvlpyn', 804050, 56, 'Computer'),
#  ('ggrtyyprmp', 862683, 80, 'Music'),
#  ('jrjcrovvdz', 893290, 92, 'MISC'),
#  ('njvyhswwwf', 868283, 85, 'Music'),
#  ('yplhokfwbk', 893575, 78, 'MISC'),
#  ('qqqimndgqz', 804344, 89, 'Groceries'),
#  ('cfbpmrzpph', 844353, 17, 'Books'),
#  ('reqyezsvki', 851493, 20, 'Music'),
#  ('ccieuzeczv', 865727, 21, 'Computer'),
#  ('qrvtlaamqe', 840222, 84, 'MISC'),
#  ('hepmalydkd', 849265, 15, 'Music'),
#  ('irrqttzsel', 889344, 90, 'Movies'),
#  ('ulqkcgqmfq', 802625, 22, 'Movies'),
#  ('tgxttdptwm', 838907, 29, 'Music'),
#  ('ztxwyqgoux', 886824, 21, 'Music'),
#  ('lgmaeeifpk', 821087, 96, 'Groceries'),
#  ('felfnqryha', 808473, 48, 'MISC'),
#  ('htjxurhlek', 831436, 3, 'Music'),
#  ('qclojvocio', 875616, 42, 'Computer'),
#  ('xnxwvmfpyt', 883020, 43, 'MISC'),
#  ('lrlsgvpbxs', 865027, 64, 'MISC'),
#  ('hxpymkkcug', 864946, 67, 'Books'),
#  ('nbuppxnxeg', 858259, 30, 'Computer'),
#  ('ykoikagsci', 881075, 23, 'Books'),
#  ('zfbbrltvns', 816115, 50, 'Computer'),
#  ('nbfzpnacwk', 881416, 19, 'Groceries'),
#  ('vwinsrkkjm', 817306, 92, 'Books'),
#  ('hfnoeurqip', 887666, 72, 'Computer'),
#  ('pdrkyifozy', 870127, 72, 'Computer'),
#  ('tjlzhhieuk', 853908, 13, 'Books'),
#  ('unsyfcdafx', 815933, 40, 'Movies'),
#  ('wkxkvkvenl', 834942, 9, 'Books'),
#  ('naihwpibuq', 883966, 81, 'Books'),
#  ('arnstxnlbb', 819255, 53, 'Groceries'),
#  ('wxtligdtxa', 885287, 52, 'Music'),
#  ('wcbhklqsjs', 854477, 72, 'MISC'),
#  ('ufsmpvspdi', 892184, 39, 'Books'),
#  ('fvxmgsqkin', 864664, 33, 'Movies'),
#  ('yxoyxvjfuo', 898101, 51, 'Movies'),
#  ('rkuomwpnlq', 802483, 74, 'Computer'),
#  ('gliufxyryd', 811264, 98, 'Movies'),
#  ('gddotvyrmy', 876823, 19, 'Movies'),
#  ('jfoygsrrvv', 892271, 60, 'Groceries'),
#  ('gatbciozbd', 854168, 20, 'Movies'),
#  ('gwuttfplbd', 867737, 7, 'Books'),
#  ('ljhqykkhbt', 851175, 56, 'Movies'),
#  ('irgoyjenxb', 860871, 17, 'Groceries'),
#  ('bbkxxganri', 832959, 30, 'Books'),
#  ('rsbkximvct', 891370, 16, 'Groceries'),
#  ('etrscrxrah', 810580, 50, 'Computer'),
#  ('ozmbxnxkar', 812007, 35, 'Movies'),
#  ('cptnucyypk', 890986, 27, 'Music'),
#  ('sibxfulpdw', 820265, 29, 'MISC'),
#  ('chqmavniup', 899562, 53, 'MISC'),
#  ('yzkbqouklr', 888868, 60, 'Computer'),
#  ('ueqcvjlkzb', 840078, 21, 'Computer'),
#  ('ikjmxwkxyi', 848853, 9, 'Computer'),
#  ('wwaaedeqpe', 864332, 18, 'Music'),
#  ('combrngcgt', 861728, 47, 'Computer'),
#  ('jiplemzgbt', 825364, 87, 'Movies'),
#  ('gnsnjiskxl', 820250, 63, 'MISC'),
#  ('bjqmpnmtfi', 848819, 64, 'MISC'),
#  ('khuabrrfsv', 889956, 47, 'Groceries'),
#  ('vpaulvprae', 897947, 3, 'MISC'),
#  ('geqggicazv', 816114, 85, 'Movies'),
#  ('cggjgcpeqt', 883522, 91, 'Movies'),
#  ('gqborpsgva', 829544, 33, 'MISC'),
#  ('cuhxvknpes', 872239, 41, 'Books'),
#  ('wnnzbobyae', 823176, 48, 'MISC'),
#  ('kukekephre', 869846, 54, 'Music'),
#  ('mffxvsmgil', 899988, 32, 'Movies'),
#  ('ybxpoeqyaj', 847769, 33, 'Groceries'),
#  ('qcbnirwopw', 805000, 81, 'MISC'),
#  ('uafogisebk', 876717, 7, 'Music'),
#  ('isgzkcdnyi', 810232, 69, 'Music'),
#  ('raykgvewsd', 892273, 10, 'Music'),
#  ('sxjgplffxo', 869479, 28, 'MISC'),
#  ('adrmkoizzi', 897813, 21, 'MISC'),
#  ('sugjmvpynf', 892526, 56, 'Books'),
#  ('oeudkrnfxm', 813987, 31, 'MISC'),
#  ('jcvgtipqyt', 866357, 21, 'Books'),
#  ('vblgzirizt', 863181, 23, 'MISC'),
#  ('qvcgwdxxkp', 834557, 24, 'MISC'),
#  ('dygffenziu', 898633, 69, 'Movies'),
#  ('qmxllqcfet', 849914, 42, 'MISC'),
#  ('syhbmthhqv', 809926, 6, 'Groceries'),
#  ('htspkfhryh', 837370, 82, 'Groceries'),
#  ('gedvsazyvj', 827545, 41, 'Groceries'),
#  ('zenisbqmta', 868277, 60, 'Movies'),
#  ('mlerdudofp', 837783, 95, 'MISC'),
#  ('uykaytfsnd', 871079, 82, 'Computer'),
#  ('etylatsrbv', 858838, 39, 'Movies'),
#  ('bfiqiekurx', 818553, 1, 'Books'),
#  ('vmeregfwxe', 802793, 20, 'Music'),
#  ('dhwdlwuqgs', 872837, 94, 'Groceries'),
#  ('wkjnzfdpta', 810184, 82, 'Books'),
#  ('kvfwyvsyrm', 831395, 70, 'Groceries'),
#  ('fyjlrpptmx', 837952, 83, 'MISC'),
#  ('amaozidzde', 836123, 47, 'Music'),
#  ('ffunmeydsw', 878894, 10, 'Computer'),
#  ('zzrnleomme', 894151, 5, 'Movies'),
#  ('sxcfgeaklc', 816725, 34, 'Music'),
#  ('xooojmyiur', 857576, 85, 'Books'),
#  ('hyxkkwzqou', 838663, 46, 'Computer'),
#  ('dtdfzlphff', 893862, 51, 'MISC'),
#  ('kyekdydllj', 875564, 75, 'Music'),
#  ('roepmuajdk', 870387, 51, 'Groceries'),
#  ('twayhvhfyi', 814178, 29, 'Books'),
#  ('kllugfmgxr', 822263, 70, 'Music'),
#  ('quxugigaig', 840781, 93, 'Music'),
#  ('ksmpfifkhp', 824061, 28, 'Computer'),
#  ('iyxhpjipjs', 852845, 47, 'Groceries'),
#  ('mkmxsqukae', 873175, 2, 'MISC'),
#  ('xbyoriaebm', 840954, 29, 'Music'),
#  ('jjmjiqnrst', 835934, 47, 'Books'),
#  ('lmihwvrpph', 877037, 15, 'MISC'),
#  ('jooelwxyow', 874592, 49, 'MISC'),
#  ('rtzxpwozus', 890475, 34, 'MISC'),
#  ('doatrxrvse', 891888, 87, 'Movies'),
#  ('dorzlevugc', 849777, 21, 'Books'),
#  ('gzqsmssrvb', 823790, 29, 'Books'),
#  ('wnwhrewche', 884249, 44, 'Computer'),
#  ('garwihnfey', 828001, 30, 'Groceries'),
#  ('jrwocosxcr', 865558, 48, 'Groceries'),
#  ('brqjkparde', 873342, 23, 'MISC'),
#  ('bzwkzislku', 878294, 78, 'Computer'),
#  ('wffxvksbcr', 875129, 4, 'Books'),
#  ('dgdclmmqlu', 855139, 9, 'Books'),
#  ('reuvkpfblo', 844046, 68, 'Groceries'),
#  ('xuwiksiehg', 881913, 25, 'Groceries'),
#  ('kdnvhdadww', 800070, 24, 'MISC'),
#  ('napobepxib', 867695, 41, 'Groceries'),
#  ('pnyyvgxdof', 849644, 31, 'Movies'),
#  ('mbuupsvuhq', 888123, 75, 'MISC'),
#  ('kshrdbyosd', 869901, 82, 'MISC'),
#  ('lfabrbducc', 895639, 72, 'Movies'),
#  ('luaguldqpo', 876312, 98, 'Movies'),
#  ('orwgcrrmja', 820587, 28, 'Computer'),
#  ('csmumuzswe', 855352, 98, 'Computer'),
#  ('ctoaviyhdm', 875586, 12, 'Groceries'),
#  ('qonpajstsg', 859716, 83, 'Groceries'),
#  ('mvpipprtxt', 823386, 17, 'Books'),
#  ('ydkutursvm', 897319, 22, 'Computer'),
#  ('jpafkbrwps', 862480, 76, 'MISC'),
#  ('weovsyywyc', 839381, 50, 'Groceries'),
#  ('tonxnhzpfc', 867480, 33, 'Music'),
#  ('ffpzykpcpf', 813312, 79, 'Music'),
#  ('irijgfcexm', 806570, 58, 'Books'),
#  ('kkyrnyulqd', 832309, 83, 'Groceries'),
#  ('ehannrkzts', 803840, 87, 'Groceries'),
#  ('lzmirxifbs', 878798, 64, 'Computer'),
#  ('dlwwndpmpu', 814999, 58, 'Movies'),
#  ('ewhqkueiee', 805055, 41, 'Music'),
#  ('hxymkwzalg', 868831, 58, 'Movies'),
#  ('qybkltvdph', 808974, 65, 'Music'),
#  ('wpboqayfio', 858763, 35, 'Movies'),
#  ('lxfyirpwpw', 880413, 90, 'Books'),
#  ('bfevnanodk', 803871, 2, 'Computer'),
#  ('zbljllvqzg', 867707, 46, 'MISC'),
#  ('svtxcxvdba', 816200, 55, 'Music'),
#  ('embhsihvnn', 878266, 30, 'Movies'),
#  ('rchgbvkqun', 814168, 21, 'Computer'),
#  ('vhrdpibmsw', 887827, 80, 'Music'),
#  ('evmlcdtocj', 801190, 35, 'Movies'),
#  ('sfyrqaaoib', 811629, 56, 'MISC'),
#  ('kgesmzpkal', 856691, 55, 'Movies'),
#  ('xgruethifw', 818607, 67, 'Computer'),
#  ('djcbepviuw', 809549, 90, 'Movies'),
#  ('zxmeyavlxs', 873755, 72, 'Movies'),
#  ('bvfwiqgoyh', 861167, 97, 'Groceries'),
#  ('cizbtnmgeq', 838715, 13, 'Groceries'),
#  ('bxfoyuabdg', 850449, 51, 'Computer'),
#  ('mfpfmusrbj', 811219, 43, 'Music'),
#  ('nmpgbbkpwg', 869460, 46, 'Groceries'),
#  ('ygadjoryoy', 867588, 30, 'Books'),
#  ('grwwxqzlkw', 805940, 24, 'MISC'),
#  ('nvravaxwye', 818147, 36, 'Computer'),
#  ('yyjpltvsmr', 820711, 21, 'Computer'),
#  ('rlpyobxzrn', 805473, 40, 'MISC'),
#  ('gpquqsdyqs', 849962, 59, 'Music'),
#  ('lwqdaclxes', 892334, 19, 'Groceries'),
#  ('mryziudupv', 865827, 94, 'Groceries'),
#  ('nqhxgyvorg', 810272, 87, 'MISC'),
#  ('lnksnzorpe', 801960, 77, 'Groceries'),
#  ('biujeawqcg', 862226, 31, 'Computer'),
#  ('avfdzzuywc', 892841, 17, 'Groceries'),
#  ('pzolroaacv', 846787, 6, 'Groceries'),
#  ('sephxzxvkd', 858130, 58, 'Groceries'),
#  ('qoidpavgeb', 854060, 42, 'MISC'),
#  ('swmuxhqgoc', 805271, 22, 'Movies'),
#  ('gqzhcuelpb', 803796, 78, 'Music'),
#  ('gnljkyqmir', 824720, 35, 'Music'),
#  ('vqokvgvuxe', 855863, 28, 'Computer'),
#  ('gkikwtwmkk', 845601, 65, 'Books'),
#  ('mzhuabphzp', 874170, 56, 'MISC'),
#  ('ejodqoryui', 829097, 4, 'Groceries'),
#  ('xdejuhioyd', 889830, 12, 'Movies'),
#  ('otahwzgsde', 894959, 41, 'Computer'),
#  ('sffnkjkome', 818494, 71, 'Movies'),
#  ('rfxasbtqez', 890202, 89, 'Music'),
#  ('hckwsqxhgo', 822427, 27, 'Movies'),
#  ('xbyxhzzcyh', 815129, 49, 'Movies'),
#  ('yqakmnaxab', 844347, 27, 'Music'),
#  ('ipxfdllhbu', 890748, 38, 'Music'),
#  ('xxocpnlwue', 832543, 1, 'Music'),
#  ('rnpnpppmbm', 852678, 37, 'Books'),
#  ('zukctjivqx', 880748, 6, 'Movies'),
#  ('qitguewiil', 858493, 39, 'Groceries'),
#  ('lzqiuldthh', 832688, 37, 'Computer'),
#  ('uuiyfshfuw', 849033, 8, 'Music'),
#  ('cmsdurkrdc', 883187, 71, 'Movies'),
#  ('ytqbveljvj', 858558, 66, 'MISC'),
#  ('eitsbyvogs', 812947, 31, 'MISC'),
#  ('ckdccnkblt', 839087, 89, 'Computer'),
#  ('lylhpcsaty', 882619, 81, 'Music'),
#  ('toyobxwjwy', 820330, 58, 'MISC'),
#  ('rzfqxvtfvp', 848395, 35, 'Movies'),
#  ('hkoslcyfgb', 814698, 47, 'MISC'),
#  ('fpnxetrepf', 807736, 36, 'Books'),
#  ('cydwwtzjve', 812483, 7, 'Books'),
#  ('fofqdgpbdc', 880366, 28, 'Music'),
#  ('hqycqbedxf', 865428, 5, 'Movies'),
#  ('mxijgwfugz', 818608, 96, 'Groceries'),
#  ('gzxyukzuls', 895167, 84, 'Groceries'),
#  ('sjqrrylvjn', 835704, 44, 'MISC'),
#  ('btwphooxsp', 870116, 12, 'Computer'),
#  ('wpemkrjbuj', 857644, 51, 'Computer'),
#  ('ibwublyhyk', 847108, 31, 'Computer'),
#  ('jffvcpnwlk', 876588, 59, 'Music'),
#  ('ccydsyguhn', 818305, 82, 'Books'),
#  ('tlnrbajetf', 872344, 16, 'Computer'),
#  ('jnlmnkbrna', 806443, 20, 'Books'),
#  ('bebiywlyjv', 818115, 32, 'Groceries'),
#  ('xpbaemkqyt', 851539, 64, 'Computer'),
#  ('fvhklwgaay', 848838, 67, 'Movies'),
#  ('cfzbsueedy', 853376, 85, 'Movies'),
#  ('edukwkgdtl', 884545, 34, 'Movies'),
#  ('fkoabzvmak', 863663, 33, 'Music'),
#  ('rpmfptukwf', 883470, 73, 'MISC'),
#  ('vbztlpbhsx', 859179, 55, 'Groceries'),
#  ('lcefrphpdu', 867060, 17, 'MISC'),
#  ('pwddrsoexf', 897640, 39, 'Movies'),
#  ('nnkfieelpo', 885890, 37, 'Movies'),
#  ('jjbgkouluv', 822800, 81, 'MISC'),
#  ('syzabdfvjr', 804297, 65, 'Computer'),
#  ('kovinnmcbs', 801560, 16, 'Books'),
#  ('dksqvqkcjr', 876021, 32, 'Groceries'),
#  ('zpplacdbve', 889368, 13, 'Books'),
#  ('edjmbvstuj', 830287, 84, 'Groceries'),
#  ('qwrnvydnta', 840123, 8, 'Music'),
#  ('feqkunnqxh', 851614, 92, 'Movies'),
#  ('rirlhyqiwf', 875369, 62, 'Computer'),
#  ('jpskdpgnzg', 807780, 42, 'Groceries'),
#  ('afceoztvew', 866515, 69, 'Books'),
#  ('zxcemlqgvv', 874340, 37, 'Music'),
#  ('lmbhtjsfxb', 830447, 96, 'Music'),
#  ('pifoqkklco', 805034, 23, 'Movies'),
#  ('ojgifcgaxx', 812328, 81, 'Computer'),
#  ('oheugeuozz', 836749, 16, 'Movies'),
#  ('tnkangtlcr', 854551, 67, 'Movies'),
#  ('llnbchziye', 828454, 21, 'Movies'),
#  ('hqlrcegbip', 877519, 28, 'Movies'),
#  ('rxhbdxrppi', 857735, 15, 'MISC'),
#  ('xcjtwannnt', 801937, 20, 'Groceries'),
#  ('brocvagdzn', 893868, 59, 'Groceries'),
#  ('wtwsvnvwxa', 840601, 66, 'MISC'),
#  ('kkzedwirdg', 859269, 3, 'Movies'),
#  ('crroubnbcj', 852694, 90, 'Music'),
#  ('huhunqirth', 818937, 22, 'Groceries'),
#  ('ydcyqcaqyy', 888492, 30, 'Groceries'),
#  ('jnpzpuwyql', 893599, 2, 'MISC'),
#  ('nlhmztlqof', 832029, 32, 'Books'),
#  ('oaerdrjhiq', 806614, 79, 'Groceries'),
#  ('eqxubzwdzm', 850786, 50, 'Books'),
#  ('jkescsjvih', 833730, 79, 'Movies'),
#  ('mwbrllsjar', 876379, 40, 'Computer'),
#  ('oirsjwbcbn', 820437, 3, 'Computer'),
#  ('lbrsjtcnrb', 848934, 44, 'Computer'),
#  ('mtpfrcbzxv', 841981, 70, 'Movies'),
#  ('dndpkvanzy', 898361, 84, 'Movies'),
#  ('nklacrbzuc', 863050, 68, 'Movies'),
#  ('puphgwmkoo', 860833, 78, 'Books'),
#  ('hhktkhkpsf', 853049, 38, 'Computer'),
#  ('gbnfjksrfm', 899211, 78, 'MISC'),
#  ('dotiuqetjy', 884312, 19, 'Groceries'),
#  ('clphvxpbpg', 891768, 82, 'Books'),
#  ('tgmgirytwx', 857584, 76, 'Books'),
#  ('joellukeqq', 881845, 73, 'Movies'),
#  ('bmbysfkzez', 849179, 86, 'Music'),
#  ('cjiwoucnqr', 846147, 88, 'Movies'),
#  ('xpikwqkfyb', 887426, 6, 'Music'),
#  ('cancelqbrh', 805840, 3, 'Books'),
#  ('dhqybmwtmh', 836866, 9, 'Computer'),
#  ('zjvfdbhhfl', 838890, 26, 'MISC'),
#  ('uviktspixc', 885499, 65, 'Books'),
#  ('eyccwfjfqg', 878149, 26, 'Movies'),
#  ('ukfwfqnomz', 853969, 15, 'Groceries'),
#  ('kwdkntnutx', 889598, 28, 'Music'),
#  ('cdjpmnnqxp', 879666, 73, 'Computer'),
#  ('rmcwnitcik', 817642, 7, 'Books'),
#  ('guobyhvpoy', 867616, 86, 'Music'),
#  ('jtjhdyknab', 803207, 50, 'Computer'),
#  ('pitzesbayd', 843823, 63, 'Movies'),
#  ('skcwrgclby', 824664, 97, 'Music'),
#  ('aiumvkalrj', 861303, 81, 'Music'),
#  ('abjwpqzjxg', 816202, 83, 'MISC'),
#  ('qvryiqrlrf', 804360, 10, 'Music'),
#  ('uebprxmnsn', 891796, 75, 'Groceries'),
#  ('ktwwlylffk', 826507, 50, 'MISC'),
#  ('azrivftpch', 881296, 57, 'Movies'),
#  ('vzckplhiab', 800078, 96, 'Groceries'),
#  ('gouejlicyf', 849007, 51, 'Books'),
#  ('xqdbhoxjth', 804738, 79, 'MISC'),
#  ('tnpdprwubw', 887044, 16, 'MISC'),
#  ('owknhtvcgi', 825652, 17, 'Movies'),
#  ('oxwsqpxeju', 865370, 25, 'Movies'),
#  ('xpnodmriai', 813933, 8, 'MISC'),
#  ('owmptystql', 848161, 79, 'Books'),
#  ('fdkxkpnwju', 836707, 98, 'Books'),
#  ('wzkygeocfc', 817910, 53, 'Books'),
#  ('mjzkyhwqku', 802472, 9, 'Groceries'),
#  ('qbfoxdgvyx', 868019, 58, 'Computer'),
#  ('tdmwlecpnz', 814857, 30, 'Computer'),
#  ('ypykzknhng', 898940, 58, 'Music'),
#  ('dzmahxkxrg', 887256, 75, 'Books'),
#  ('ycrlakfftk', 880631, 31, 'Groceries'),
#  ('dundhfgefj', 836825, 39, 'Movies'),
#  ('xjgqkycyvp', 840093, 3, 'MISC'),
#  ('jocjhlioot', 842111, 85, 'MISC'),
#  ('xvfojulxti', 825250, 93, 'Movies'),
#  ('iwcsjahxdd', 841413, 11, 'Books'),
#  ('bdmkiqopjk', 881475, 22, 'Computer'),
#  ('twhmaovbfp', 838365, 69, 'Groceries'),
#  ('ghlpaaduqk', 893526, 3, 'Books'),
#  ('jrbaqqkpva', 889659, 85, 'Computer'),
#  ('yrblltehvw', 827898, 76, 'Books'),
#  ('mctyhntove', 866404, 12, 'MISC'),
#  ('viectematz', 819926, 87, 'Computer'),
#  ('zlmogogjiv', 805109, 28, 'Movies'),
#  ('isglxdtmlj', 867682, 44, 'MISC'),
#  ('futjsezows', 886318, 8, 'Computer'),
#  ('bmnjiruave', 885953, 8, 'Music'),
#  ('gfugtayqqg', 867288, 91, 'Books'),
#  ('xdvacgbjce', 807994, 59, 'Music'),
#  ('rlklkwmjtq', 847517, 51, 'MISC'),
#  ('suupvphpgx', 877368, 10, 'Computer'),
#  ('bnekiyikzt', 864142, 86, 'Music'),
#  ('xyocduantz', 840600, 53, 'Music'),
#  ('uwtyguapkf', 866881, 93, 'Movies'),
#  ('piqstukkxo', 868911, 2, 'Movies'),
#  ('cskttkctln', 851646, 52, 'Groceries'),
#  ('pkbvgbvbrx', 834228, 91, 'Groceries'),
#  ('vbfempmwwq', 865818, 57, 'Computer'),
#  ('gywekfocwb', 819350, 61, 'Groceries'),
#  ('ocgbcgznhx', 823877, 43, 'Movies'),
#  ('iscicebceh', 831288, 25, 'Groceries'),
#  ('zvuzlaomiy', 842158, 45, 'Movies'),
#  ('exhujgxqvi', 825733, 85, 'Music'),
#  ('rzmqyvukcz', 870864, 33, 'Music'),
#  ('qzbjkznyhf', 865857, 97, 'Computer'),
#  ('prrboujrlu', 880642, 90, 'Computer'),
#  ('vnaroezfzj', 809739, 51, 'Music'),
#  ('xlliyxgdza', 828675, 5, 'Movies'),
#  ('ymlrkspfzj', 890699, 45, 'Books'),
#  ('bqtcwkhsoj', 877659, 27, 'MISC'),
#  ('wjfwpqcbnf', 880597, 3, 'Movies'),
#  ('rfxrxjljrd', 819082, 28, 'Movies'),
#  ('yblrifgjtv', 854864, 74, 'Music'),
#  ('wnaavfjutn', 874879, 44, 'Movies'),
#  ('lqehkhowxw', 813891, 24, 'Movies'),
#  ('fezroxuexf', 804727, 26, 'Books'),
#  ('fzyzkgdskn', 811522, 11, 'MISC'),
#  ('aymkzvmzps', 894129, 6, 'Groceries'),
#  ('pyvpjikrwt', 849904, 17, 'Computer'),
#  ('wgdghigpfk', 875051, 4, 'Groceries')]

# %% [markdown]
# 4. Which department has the highest duplicate records? Return the department name and count of duplicate records. Assume the possibility that multiple departments could have the same highest count.

# %%
# %%sql
# select department, s from
# (
#   select department, sum(c) as s from
#     (
#       select department, count(*) as c
#       from duplicate_transactions
#       group by transaction_id, timestamp, price, department
#       having count(*) > 1
#     )
#   group by department
# )
# where s =
# (
#   select max(s) from
#     (
#       select department, sum(c) as s from
#         (
#           select department, count(*) as c
#           from duplicate_transactions
#           group by transaction_id, timestamp, price, department
#           having count(*) > 1
#         )
#       group by department
#     )
# )
# Out:
#  * sqlite:////content/drive/MyDrive/sqltraining.sqlite
# Done.
# [('Music', 33)]

# %% [markdown]
# # Task #2 Connections

# %% [markdown]
# **Problem:**
#
# Facebook’s analytics team wants to understand how users stay connected among friends on their platform.
# The team believes that understanding patterns could help improve an algorithm that matches potential friends.
# Use the friends table to address the questions below. A user can perform the following sequence of actions:
# (1) request or receive, (2) connect, and (3) block.
#
# 1. Return a list of users who blocked another user after connecting for at least 90 days.
# Show the user_id and receiver_id.
#
# 2. For each user, what is the proportion of each action? Note that the receiver_id can
# appear in multiple actions per user, only regard the latest status when calculating
# the distribution.

# %% [markdown]
# ## 1.1. Creating tables and inserting values

# %%
# %sql drop table friends_connections
# Out:
#  * sqlite:////content/drive/MyDrive/sqltraining.sqlite
# Done.
# []

# %%
# %%sql
# CREATE TABLE friends_connections (
# 	date VARCHAR,
# 	user_id FLOAT,
# 	receiver_id INTEGER,
# 	action VARCHAR
# );
# Out:
#  * sqlite:////content/drive/MyDrive/sqltraining.sqlite
# Done.
# []

# %%
data = prepare_data_from_csv('/content/drive/MyDrive/Colab Notebooks/Data/SQL_training/facebook_connections/friends_connections.csv')
data[:100]
# Out:
# "('2020-01-30', 100, 246, 'Sent'),('2020-01-01', 100, 895, 'Received'),('2020-05-03', 100, 895, 'Conn"

# %%
# %%sql insert into friends_connections values {data}
# Out:
#  * sqlite:////content/drive/MyDrive/sqltraining.sqlite
# 4841 rows affected.
# []

# %% [markdown]
# ## 1.2. Look at the tables

# %%
# %sql select * from friends_connections limit 1, 5
# Out:
#  * sqlite:////content/drive/MyDrive/sqltraining.sqlite
# Done.
# [('2020-01-01', 100.0, 895, 'Received'),
#  ('2020-05-03', 100.0, 895, 'Connected'),
#  ('2020-02-06', 101.0, 678, 'Sent'),
#  ('2020-04-14', 101.0, 678, 'Connected'),
#  ('2020-01-03', 101.0, 790, 'Sent')]

# %% [markdown]
# ## 1.3. Solution

# %% [markdown]
# 1. Return a list of users who blocked another user after connecting for at least 90 days. Show the user_id and receiver_id.

# %%
# %%sql
# select * from friends_connections
# where user_id=895 and receiver_id=100
# Out:
#  * sqlite:////content/drive/MyDrive/sqltraining.sqlite
# Done.
# []

# %%
# %%sql
# select fc1.user_id, fc1.receiver_id from friends_connections fc1
# join friends_connections fc2 on fc1.user_id=fc2.user_id and fc1.receiver_id=fc2.receiver_id
# where
# fc1.action='Connected' and fc2.action='Blocked' and JulianDay(date(fc2.date))-JulianDay(date(fc1.date)) >= 90
# Out:
#  * sqlite:////content/drive/MyDrive/sqltraining.sqlite
# Done.
# [(107.0, 415),
#  (121.0, 263),
#  (147.0, 607),
#  (149.0, 486),
#  (178.0, 697),
#  (202.0, 630),
#  (217.0, 248),
#  (272.0, 801),
#  (273.0, 288),
#  (299.0, 609),
#  (320.0, 313),
#  (333.0, 265),
#  (365.0, 532),
#  (405.0, 316),
#  (445.0, 128),
#  (455.0, 496),
#  (468.0, 650),
#  (475.0, 872),
#  (494.0, 592),
#  (508.0, 517),
#  (537.0, 581),
#  (538.0, 103),
#  (557.0, 427),
#  (567.0, 226),
#  (586.0, 877),
#  (606.0, 906),
#  (620.0, 760),
#  (646.0, 884),
#  (651.0, 259),
#  (675.0, 916),
#  (695.0, 330),
#  (714.0, 324),
#  (749.0, 198),
#  (760.0, 953),
#  (793.0, 221),
#  (811.0, 496),
#  (847.0, 371),
#  (877.0, 121),
#  (878.0, 286),
#  (881.0, 624),
#  (906.0, 792),
#  (912.0, 760),
#  (986.0, 751)]

# %% [markdown]
# 2. For each user, what is the proportion of each action? Note that the receiver_id can
# appear in multiple actions per user, only regard the latest status when calculating
# the distribution.

# %%
# %%sql
# select
# t.user_id,
# round(t.sent_count/t.sum, 2) prop_sent,
# round(t.received_count/t.sum, 2) prop_received,
# round(t.connected_count/t.sum, 2) prop_connected,
# round(t.blocked_count/t.sum, 2) prop_blocked
# from
# (
#   select
#   user_tbl.user_id,
#   cast(ifnull(sent_tbl.c, 0) as float) sent_count,
#   cast(ifnull(received_tbl.c, 0) as float) received_count,
#   cast(ifnull(connected_tbl.c, 0) as float) connected_count,
#   cast(ifnull(blocked_tbl.c, 0) as float) blocked_count,
#   ifnull(sent_tbl.c, 0) + ifnull(received_tbl.c, 0) + ifnull(connected_tbl.c, 0) + ifnull(blocked_tbl.c, 0) sum
#   from
#   (
#     select distinct user_id from friends_connections group by user_id, receiver_id
#   ) as user_tbl
#
#   left join
#   (
#     select user_id, count(*) as c from
#     (
#       select temp.* from
#       (
#         select max(date), user_id, receiver_id, action
#         from friends_connections
#         group by user_id, receiver_id
#       ) temp
#       where action='Sent'
#     )
#     group by user_id
#   ) sent_tbl on user_tbl.user_id = sent_tbl.user_id
#
#   left join
#   (
#     select user_id, count(*) as c from
#     (
#       select temp.* from
#       (
#         select max(date), user_id, receiver_id, action
#         from friends_connections
#         group by user_id, receiver_id
#       ) temp
#       where action='Received'
#     )
#     group by user_id
#   ) received_tbl on user_tbl.user_id = received_tbl.user_id
#
#   left join
#   (
#     select user_id, count(*) as c from
#     (
#       select temp.* from
#       (
#         select max(date), user_id, receiver_id, action
#         from friends_connections
#         group by user_id, receiver_id
#       ) temp
#       where action='Connected'
#     )
#     group by user_id
#   ) connected_tbl on user_tbl.user_id = connected_tbl.user_id
#
#   left join
#   (
#     select user_id, count(*) as c from
#     (
#       select temp.* from
#       (
#         select max(date), user_id, receiver_id, action
#         from friends_connections
#         group by user_id, receiver_id
#       ) temp
#       where action='Blocked'
#     )
#     group by user_id
#   ) blocked_tbl on user_tbl.user_id = blocked_tbl.user_id
# ) as t
# Out:
#  * sqlite:////content/drive/MyDrive/sqltraining.sqlite
# Done.
# [(100.0, 0.5, 0.0, 0.5, 0.0),
#  (101.0, 0.5, 0.0, 0.5, 0.0),
#  (102.0, 0.0, 0.0, 1.0, 0.0),
#  (103.0, 0.0, 0.0, 0.0, 1.0),
#  (104.0, 0.0, 0.0, 0.5, 0.5),
#  (105.0, 0.0, 0.0, 0.0, 1.0),
#  (106.0, 0.0, 0.0, 1.0, 0.0),
#  (107.0, 0.5, 0.0, 0.25, 0.25),
#  (108.0, 0.67, 0.0, 0.33, 0.0),
#  (109.0, 0.25, 0.5, 0.25, 0.0),
#  (110.0, 0.6, 0.0, 0.4, 0.0),
#  (111.0, 0.0, 0.5, 0.5, 0.0),
#  (112.0, 0.0, 1.0, 0.0, 0.0),
#  (113.0, 0.0, 0.0, 1.0, 0.0),
#  (114.0, 0.0, 0.0, 1.0, 0.0),
#  (115.0, 0.0, 0.0, 1.0, 0.0),
#  (116.0, 0.2, 0.0, 0.6, 0.2),
#  (117.0, 0.2, 0.2, 0.2, 0.4),
#  (118.0, 0.0, 0.0, 1.0, 0.0),
#  (119.0, 0.0, 0.0, 1.0, 0.0),
#  (120.0, 0.0, 0.5, 0.5, 0.0),
#  (121.0, 0.0, 0.6, 0.2, 0.2),
#  (122.0, 0.0, 0.0, 1.0, 0.0),
#  (123.0, 1.0, 0.0, 0.0, 0.0),
#  (124.0, 0.0, 0.0, 1.0, 0.0),
#  (125.0, 0.0, 0.0, 1.0, 0.0),
#  (126.0, 0.5, 0.5, 0.0, 0.0),
#  (127.0, 0.5, 0.0, 0.5, 0.0),
#  (128.0, 0.0, 0.33, 0.67, 0.0),
#  (129.0, 0.0, 0.33, 0.67, 0.0),
#  (130.0, 0.5, 0.0, 0.0, 0.5),
#  (131.0, 1.0, 0.0, 0.0, 0.0),
#  (132.0, 0.0, 0.0, 1.0, 0.0),
#  (133.0, 0.25, 0.0, 0.75, 0.0),
#  (134.0, 0.0, 0.5, 0.5, 0.0),
#  (135.0, 0.25, 0.25, 0.5, 0.0),
#  (136.0, 0.0, 0.5, 0.5, 0.0),
#  (137.0, 0.4, 0.0, 0.6, 0.0),
#  (138.0, 0.0, 0.0, 1.0, 0.0),
#  (139.0, 0.0, 0.0, 0.5, 0.5),
#  (140.0, 0.0, 0.0, 0.75, 0.25),
#  (141.0, 0.33, 0.0, 0.67, 0.0),
#  (142.0, 0.33, 0.0, 0.33, 0.33),
#  (143.0, 0.0, 0.25, 0.75, 0.0),
#  (144.0, 0.0, 0.2, 0.8, 0.0),
#  (145.0, 0.0, 0.0, 0.5, 0.5),
#  (146.0, 0.25, 0.5, 0.25, 0.0),
#  (147.0, 0.2, 0.2, 0.4, 0.2),
#  (148.0, 0.5, 0.0, 0.5, 0.0),
#  (149.0, 0.2, 0.0, 0.6, 0.2),
#  (150.0, 0.5, 0.0, 0.5, 0.0),
#  (151.0, 0.0, 0.0, 1.0, 0.0),
#  (152.0, 0.0, 0.0, 1.0, 0.0),
#  (153.0, 0.5, 0.5, 0.0, 0.0),
#  (154.0, 0.0, 0.25, 0.75, 0.0),
#  (155.0, 0.0, 0.5, 0.5, 0.0),
#  (156.0, 0.25, 0.25, 0.5, 0.0),
#  (157.0, 0.2, 0.4, 0.4, 0.0),
#  (158.0, 0.25, 0.0, 0.5, 0.25),
#  (159.0, 0.0, 0.0, 1.0, 0.0),
#  (160.0, 0.5, 0.5, 0.0, 0.0),
#  (161.0, 0.4, 0.0, 0.6, 0.0),
#  (162.0, 0.0, 0.0, 1.0, 0.0),
#  (163.0, 0.4, 0.4, 0.2, 0.0),
#  (164.0, 0.0, 0.0, 0.67, 0.33),
#  (165.0, 0.0, 0.0, 1.0, 0.0),
#  (166.0, 0.0, 0.0, 0.0, 1.0),
#  (167.0, 0.0, 0.2, 0.8, 0.0),
#  (168.0, 0.0, 0.0, 0.4, 0.6),
#  (169.0, 0.0, 0.0, 1.0, 0.0),
#  (170.0, 0.0, 0.0, 0.8, 0.2),
#  (171.0, 0.0, 0.0, 1.0, 0.0),
#  (172.0, 0.0, 0.33, 0.67, 0.0),
#  (173.0, 0.0, 0.0, 1.0, 0.0),
#  (174.0, 0.5, 0.0, 0.5, 0.0),
#  (175.0, 0.0, 0.0, 1.0, 0.0),
#  (176.0, 0.0, 0.0, 1.0, 0.0),
#  (177.0, 0.0, 0.0, 1.0, 0.0),
#  (178.0, 0.0, 0.0, 0.67, 0.33),
#  (179.0, 0.5, 0.0, 0.5, 0.0),
#  (180.0, 0.0, 0.0, 1.0, 0.0),
#  (181.0, 0.33, 0.33, 0.33, 0.0),
#  (182.0, 1.0, 0.0, 0.0, 0.0),
#  (183.0, 0.0, 0.0, 1.0, 0.0),
#  (184.0, 0.25, 0.0, 0.75, 0.0),
#  (185.0, 0.2, 0.0, 0.6, 0.2),
#  (186.0, 0.2, 0.0, 0.6, 0.2),
#  (187.0, 0.0, 0.0, 0.75, 0.25),
#  (188.0, 0.0, 0.5, 0.5, 0.0),
#  (189.0, 0.0, 0.0, 1.0, 0.0),
#  (190.0, 0.0, 0.0, 1.0, 0.0),
#  (191.0, 0.0, 0.2, 0.8, 0.0),
#  (192.0, 0.2, 0.2, 0.6, 0.0),
#  (193.0, 0.0, 0.0, 0.75, 0.25),
#  (194.0, 0.33, 0.0, 0.67, 0.0),
#  (195.0, 0.0, 0.0, 1.0, 0.0),
#  (196.0, 0.5, 0.0, 0.25, 0.25),
#  (197.0, 0.33, 0.0, 0.67, 0.0),
#  (198.0, 0.0, 0.0, 1.0, 0.0),
#  (199.0, 0.0, 0.0, 0.5, 0.5),
#  (200.0, 0.2, 0.0, 0.8, 0.0),
#  (201.0, 0.33, 0.33, 0.33, 0.0),
#  (202.0, 0.2, 0.0, 0.4, 0.4),
#  (203.0, 0.0, 0.0, 1.0, 0.0),
#  (204.0, 0.4, 0.2, 0.4, 0.0),
#  (205.0, 0.0, 0.0, 1.0, 0.0),
#  (206.0, 0.0, 0.0, 1.0, 0.0),
#  (207.0, 0.0, 0.0, 1.0, 0.0),
#  (208.0, 0.0, 0.0, 1.0, 0.0),
#  (209.0, 0.0, 0.25, 0.5, 0.25),
#  (210.0, 0.0, 0.5, 0.5, 0.0),
#  (211.0, 0.0, 0.0, 1.0, 0.0),
#  (212.0, 0.0, 0.0, 1.0, 0.0),
#  (213.0, 0.0, 0.0, 0.5, 0.5),
#  (214.0, 0.0, 0.0, 1.0, 0.0),
#  (215.0, 0.0, 0.33, 0.33, 0.33),
#  (216.0, 0.0, 0.5, 0.5, 0.0),
#  (217.0, 0.0, 0.2, 0.4, 0.4),
#  (218.0, 0.33, 0.0, 0.67, 0.0),
#  (219.0, 0.6, 0.0, 0.4, 0.0),
#  (220.0, 0.0, 0.5, 0.0, 0.5),
#  (221.0, 0.0, 0.2, 0.6, 0.2),
#  (222.0, 0.25, 0.25, 0.5, 0.0),
#  (223.0, 0.0, 0.25, 0.75, 0.0),
#  (224.0, 0.0, 0.0, 1.0, 0.0),
#  (225.0, 0.0, 0.25, 0.75, 0.0),
#  (226.0, 0.33, 0.0, 0.67, 0.0),
#  (227.0, 0.0, 0.0, 1.0, 0.0),
#  (228.0, 0.5, 0.0, 0.5, 0.0),
#  (229.0, 0.0, 0.0, 1.0, 0.0),
#  (230.0, 0.0, 0.0, 1.0, 0.0),
#  (231.0, 0.0, 0.0, 1.0, 0.0),
#  (232.0, 0.0, 0.0, 1.0, 0.0),
#  (233.0, 0.0, 0.0, 0.0, 1.0),
#  (234.0, 0.67, 0.0, 0.0, 0.33),
#  (235.0, 0.5, 0.0, 0.5, 0.0),
#  (236.0, 0.0, 0.0, 1.0, 0.0),
#  (237.0, 0.67, 0.0, 0.33, 0.0),
#  (238.0, 0.0, 1.0, 0.0, 0.0),
#  (239.0, 0.0, 0.0, 1.0, 0.0),
#  (240.0, 1.0, 0.0, 0.0, 0.0),
#  (241.0, 0.0, 0.0, 1.0, 0.0),
#  (242.0, 0.0, 0.5, 0.5, 0.0),
#  (243.0, 0.0, 0.0, 1.0, 0.0),
#  (244.0, 0.33, 0.33, 0.33, 0.0),
#  (245.0, 1.0, 0.0, 0.0, 0.0),
#  (246.0, 0.0, 0.67, 0.33, 0.0),
#  (247.0, 0.33, 0.33, 0.33, 0.0),
#  (248.0, 0.25, 0.0, 0.75, 0.0),
#  (249.0, 0.0, 0.0, 1.0, 0.0),
#  (250.0, 0.0, 0.0, 1.0, 0.0),
#  (251.0, 0.0, 1.0, 0.0, 0.0),
#  (252.0, 0.0, 0.0, 1.0, 0.0),
#  (253.0, 0.0, 0.0, 0.0, 1.0),
#  (254.0, 0.0, 0.5, 0.5, 0.0),
#  (255.0, 0.33, 0.0, 0.67, 0.0),
#  (256.0, 0.0, 0.33, 0.33, 0.33),
#  (257.0, 0.0, 1.0, 0.0, 0.0),
#  (258.0, 1.0, 0.0, 0.0, 0.0),
#  (259.0, 0.0, 0.5, 0.5, 0.0),
#  (260.0, 0.0, 0.0, 1.0, 0.0),
#  (261.0, 0.67, 0.0, 0.33, 0.0),
#  (262.0, 0.25, 0.0, 0.75, 0.0),
#  (263.0, 0.8, 0.0, 0.2, 0.0),
#  (264.0, 0.0, 0.0, 1.0, 0.0),
#  (265.0, 0.0, 0.0, 1.0, 0.0),
#  (266.0, 0.0, 0.2, 0.8, 0.0),
#  (267.0, 0.25, 0.0, 0.75, 0.0),
#  (268.0, 0.2, 0.0, 0.8, 0.0),
#  (269.0, 0.0, 0.0, 0.8, 0.2),
#  (270.0, 0.0, 0.0, 1.0, 0.0),
#  (271.0, 0.0, 0.2, 0.8, 0.0),
#  (272.0, 0.2, 0.2, 0.4, 0.2),
#  (273.0, 0.33, 0.0, 0.33, 0.33),
#  (274.0, 0.0, 0.0, 1.0, 0.0),
#  (275.0, 1.0, 0.0, 0.0, 0.0),
#  (276.0, 0.5, 0.0, 0.5, 0.0),
#  (277.0, 0.0, 0.0, 1.0, 0.0),
#  (278.0, 0.0, 1.0, 0.0, 0.0),
#  (279.0, 0.0, 0.0, 0.8, 0.2),
#  (280.0, 0.0, 0.2, 0.6, 0.2),
#  (281.0, 0.0, 0.33, 0.67, 0.0),
#  (282.0, 0.0, 0.5, 0.5, 0.0),
#  (283.0, 1.0, 0.0, 0.0, 0.0),
#  (284.0, 0.0, 0.25, 0.75, 0.0),
#  (285.0, 0.0, 0.0, 1.0, 0.0),
#  (286.0, 0.0, 0.2, 0.8, 0.0),
#  (287.0, 0.0, 0.0, 1.0, 0.0),
#  (288.0, 0.0, 0.0, 1.0, 0.0),
#  (289.0, 0.2, 0.2, 0.4, 0.2),
#  (290.0, 0.2, 0.4, 0.2, 0.2),
#  (291.0, 0.0, 1.0, 0.0, 0.0),
#  (292.0, 0.0, 1.0, 0.0, 0.0),
#  (293.0, 0.5, 0.5, 0.0, 0.0),
#  (294.0, 0.0, 0.0, 1.0, 0.0),
#  (295.0, 0.0, 0.2, 0.6, 0.2),
#  (296.0, 0.0, 0.5, 0.5, 0.0),
#  (297.0, 0.0, 0.4, 0.6, 0.0),
#  (298.0, 0.0, 0.0, 1.0, 0.0),
#  (299.0, 0.0, 0.0, 0.33, 0.67),
#  (300.0, 0.5, 0.0, 0.5, 0.0),
#  (301.0, 0.67, 0.33, 0.0, 0.0),
#  (302.0, 0.0, 1.0, 0.0, 0.0),
#  (303.0, 0.5, 0.0, 0.5, 0.0),
#  (304.0, 0.0, 0.5, 0.5, 0.0),
#  (305.0, 0.0, 0.5, 0.5, 0.0),
#  (306.0, 0.33, 0.0, 0.67, 0.0),
#  (307.0, 0.25, 0.5, 0.25, 0.0),
#  (308.0, 0.2, 0.0, 0.8, 0.0),
#  (309.0, 0.33, 0.0, 0.67, 0.0),
#  (310.0, 0.5, 0.0, 0.5, 0.0),
#  (311.0, 0.0, 0.0, 1.0, 0.0),
#  (312.0, 0.5, 0.0, 0.5, 0.0),
#  (313.0, 0.2, 0.2, 0.6, 0.0),
#  (314.0, 0.0, 0.25, 0.5, 0.25),
#  (315.0, 0.0, 0.0, 1.0, 0.0),
#  (316.0, 0.0, 0.0, 0.0, 1.0),
#  (317.0, 0.0, 0.0, 0.75, 0.25),
#  (318.0, 0.0, 0.33, 0.67, 0.0),
#  (319.0, 0.0, 0.0, 0.75, 0.25),
#  (320.0, 0.25, 0.25, 0.25, 0.25),
#  (321.0, 0.0, 0.0, 1.0, 0.0),
#  (322.0, 0.0, 0.4, 0.4, 0.2),
#  (323.0, 0.2, 0.2, 0.6, 0.0),
#  (324.0, 0.25, 0.25, 0.5, 0.0),
#  (325.0, 0.0, 1.0, 0.0, 0.0),
#  (326.0, 0.0, 0.0, 1.0, 0.0),
#  (327.0, 0.0, 0.2, 0.8, 0.0),
#  (328.0, 0.33, 0.0, 0.67, 0.0),
#  (329.0, 0.0, 0.25, 0.75, 0.0),
#  (330.0, 0.0, 0.25, 0.5, 0.25),
#  (331.0, 0.0, 0.0, 0.6, 0.4),
#  (332.0, 0.2, 0.2, 0.4, 0.2),
#  (333.0, 0.0, 0.0, 0.4, 0.6),
#  (334.0, 0.0, 0.2, 0.8, 0.0),
#  (335.0, 0.0, 0.0, 1.0, 0.0),
#  (336.0, 0.5, 0.0, 0.5, 0.0),
#  (337.0, 0.0, 0.25, 0.75, 0.0),
#  (338.0, 0.0, 0.0, 0.5, 0.5),
#  (339.0, 0.0, 0.2, 0.8, 0.0),
#  (340.0, 0.0, 0.0, 0.4, 0.6),
#  (341.0, 0.0, 0.0, 1.0, 0.0),
#  (342.0, 0.0, 0.0, 1.0, 0.0),
#  (343.0, 0.25, 0.0, 0.75, 0.0),
#  (344.0, 0.0, 0.67, 0.33, 0.0),
#  (345.0, 0.0, 0.25, 0.5, 0.25),
#  (346.0, 0.25, 0.0, 0.0, 0.75),
#  (347.0, 0.25, 0.25, 0.5, 0.0),
#  (348.0, 0.0, 0.0, 1.0, 0.0),
#  (349.0, 0.0, 0.0, 1.0, 0.0),
#  (350.0, 0.33, 0.0, 0.67, 0.0),
#  (351.0, 0.0, 0.0, 1.0, 0.0),
#  (352.0, 0.0, 0.0, 1.0, 0.0),
#  (353.0, 0.25, 0.0, 0.75, 0.0),
#  (354.0, 0.0, 0.33, 0.33, 0.33),
#  (355.0, 0.0, 0.0, 1.0, 0.0),
#  (356.0, 0.0, 1.0, 0.0, 0.0),
#  (357.0, 0.0, 0.2, 0.6, 0.2),
#  (358.0, 0.0, 0.5, 0.5, 0.0),
#  (359.0, 0.5, 0.5, 0.0, 0.0),
#  (360.0, 0.0, 0.5, 0.5, 0.0),
#  (361.0, 0.4, 0.0, 0.4, 0.2),
#  (362.0, 0.0, 0.25, 0.75, 0.0),
#  (363.0, 0.0, 0.0, 0.5, 0.5),
#  (364.0, 0.25, 0.25, 0.5, 0.0),
#  (365.0, 0.0, 0.0, 0.0, 1.0),
#  (366.0, 0.4, 0.2, 0.4, 0.0),
#  (367.0, 0.0, 0.0, 1.0, 0.0),
#  (368.0, 0.0, 0.0, 1.0, 0.0),
#  (369.0, 0.0, 0.0, 1.0, 0.0),
#  (370.0, 0.0, 0.0, 1.0, 0.0),
#  (371.0, 0.0, 0.33, 0.33, 0.33),
#  (372.0, 0.0, 0.0, 1.0, 0.0),
#  (373.0, 0.2, 0.0, 0.4, 0.4),
#  (374.0, 0.5, 0.0, 0.5, 0.0),
#  (375.0, 0.0, 0.67, 0.33, 0.0),
#  (376.0, 0.0, 0.0, 0.67, 0.33),
#  (377.0, 0.0, 0.0, 1.0, 0.0),
#  (378.0, 0.0, 0.33, 0.67, 0.0),
#  (379.0, 0.33, 0.0, 0.67, 0.0),
#  (380.0, 0.0, 0.33, 0.67, 0.0),
#  (381.0, 0.33, 0.0, 0.67, 0.0),
#  (382.0, 0.0, 0.0, 1.0, 0.0),
#  (383.0, 0.4, 0.0, 0.4, 0.2),
#  (384.0, 0.2, 0.0, 0.4, 0.4),
#  (385.0, 0.0, 0.0, 1.0, 0.0),
#  (386.0, 0.0, 0.0, 1.0, 0.0),
#  (387.0, 0.5, 0.25, 0.25, 0.0),
#  (388.0, 0.2, 0.2, 0.4, 0.2),
#  (389.0, 0.5, 0.5, 0.0, 0.0),
#  (390.0, 0.0, 0.25, 0.5, 0.25),
#  (391.0, 0.0, 0.0, 1.0, 0.0),
#  (392.0, 0.0, 0.0, 0.67, 0.33),
#  (393.0, 0.5, 0.0, 0.5, 0.0),
#  (394.0, 0.0, 0.0, 0.5, 0.5),
#  (395.0, 0.25, 0.5, 0.25, 0.0),
#  (396.0, 0.0, 1.0, 0.0, 0.0),
#  (397.0, 0.0, 0.0, 1.0, 0.0),
#  (398.0, 0.25, 0.0, 0.75, 0.0),
#  (399.0, 0.0, 0.0, 0.0, 1.0),
#  (400.0, 0.0, 0.0, 1.0, 0.0),
#  (401.0, 0.0, 0.33, 0.33, 0.33),
#  (402.0, 0.0, 0.25, 0.25, 0.5),
#  (403.0, 0.0, 1.0, 0.0, 0.0),
#  (404.0, 0.25, 0.0, 0.25, 0.5),
#  (405.0, 0.67, 0.0, 0.0, 0.33),
#  (406.0, 0.0, 0.5, 0.5, 0.0),
#  (407.0, 0.0, 0.0, 1.0, 0.0),
#  (408.0, 1.0, 0.0, 0.0, 0.0),
#  (409.0, 0.0, 0.0, 1.0, 0.0),
#  (410.0, 0.5, 0.0, 0.0, 0.5),
#  (411.0, 0.0, 0.0, 0.67, 0.33),
#  (412.0, 0.0, 0.0, 1.0, 0.0),
#  (413.0, 0.0, 0.0, 1.0, 0.0),
#  (414.0, 0.0, 0.0, 1.0, 0.0),
#  (415.0, 0.0, 0.33, 0.33, 0.33),
#  (416.0, 0.2, 0.0, 0.6, 0.2),
#  (417.0, 0.0, 0.0, 1.0, 0.0),
#  (418.0, 0.0, 0.2, 0.6, 0.2),
#  (419.0, 0.0, 0.6, 0.4, 0.0),
#  (420.0, 0.0, 1.0, 0.0, 0.0),
#  (421.0, 0.0, 0.5, 0.5, 0.0),
#  (422.0, 0.0, 0.2, 0.4, 0.4),
#  (423.0, 0.0, 0.0, 1.0, 0.0),
#  (424.0, 0.0, 0.0, 1.0, 0.0),
#  (425.0, 0.4, 0.0, 0.6, 0.0),
#  (426.0, 0.0, 0.33, 0.67, 0.0),
#  (427.0, 0.0, 1.0, 0.0, 0.0),
#  (428.0, 0.5, 0.0, 0.5, 0.0),
#  (429.0, 0.0, 1.0, 0.0, 0.0),
#  (430.0, 0.0, 0.0, 1.0, 0.0),
#  (431.0, 0.33, 0.0, 0.67, 0.0),
#  (432.0, 0.0, 0.5, 0.5, 0.0),
#  (433.0, 0.0, 0.0, 1.0, 0.0),
#  (434.0, 0.33, 0.33, 0.33, 0.0),
#  (435.0, 0.0, 0.0, 1.0, 0.0),
#  (436.0, 0.2, 0.2, 0.6, 0.0),
#  (437.0, 0.0, 0.0, 1.0, 0.0),
#  (438.0, 0.2, 0.4, 0.4, 0.0),
#  (439.0, 0.0, 0.0, 1.0, 0.0),
#  (440.0, 0.0, 0.0, 1.0, 0.0),
#  (441.0, 0.0, 0.0, 0.0, 1.0),
#  (442.0, 1.0, 0.0, 0.0, 0.0),
#  (443.0, 0.5, 0.0, 0.5, 0.0),
#  (444.0, 0.2, 0.0, 0.8, 0.0),
#  (445.0, 0.2, 0.2, 0.4, 0.2),
#  (446.0, 0.2, 0.0, 0.4, 0.4),
#  (447.0, 0.0, 0.0, 1.0, 0.0),
#  (448.0, 0.0, 0.0, 0.5, 0.5),
#  (449.0, 0.2, 0.4, 0.4, 0.0),
#  (450.0, 0.25, 0.25, 0.25, 0.25),
#  (451.0, 0.0, 0.0, 1.0, 0.0),
#  (452.0, 0.5, 0.25, 0.25, 0.0),
#  (453.0, 0.2, 0.2, 0.6, 0.0),
#  (454.0, 0.0, 0.0, 1.0, 0.0),
#  (455.0, 0.0, 0.0, 0.5, 0.5),
#  (456.0, 0.2, 0.4, 0.4, 0.0),
#  (457.0, 0.0, 0.0, 0.0, 1.0),
#  (458.0, 0.0, 0.5, 0.5, 0.0),
#  (459.0, 0.0, 0.33, 0.67, 0.0),
#  (460.0, 0.0, 0.0, 0.5, 0.5),
#  (461.0, 0.0, 0.0, 1.0, 0.0),
#  (462.0, 0.33, 0.67, 0.0, 0.0),
#  (463.0, 0.0, 0.0, 0.67, 0.33),
#  (464.0, 0.0, 0.0, 1.0, 0.0),
#  (465.0, 0.0, 0.0, 1.0, 0.0),
#  (466.0, 0.0, 0.25, 0.5, 0.25),
#  (467.0, 0.6, 0.0, 0.4, 0.0),
#  (468.0, 0.25, 0.25, 0.25, 0.25),
#  (469.0, 0.2, 0.2, 0.6, 0.0),
#  (470.0, 0.0, 0.0, 0.0, 1.0),
#  (471.0, 0.0, 1.0, 0.0, 0.0),
#  (472.0, 0.0, 0.0, 1.0, 0.0),
#  (473.0, 0.0, 0.0, 1.0, 0.0),
#  (474.0, 0.4, 0.0, 0.6, 0.0),
#  (475.0, 0.2, 0.0, 0.4, 0.4),
#  (476.0, 0.0, 0.0, 0.75, 0.25),
#  (477.0, 0.0, 0.5, 0.25, 0.25),
#  (478.0, 0.0, 0.2, 0.6, 0.2),
#  (479.0, 0.5, 0.0, 0.5, 0.0),
#  (480.0, 0.0, 0.0, 0.8, 0.2),
#  (481.0, 0.0, 0.25, 0.75, 0.0),
#  (482.0, 0.0, 0.0, 1.0, 0.0),
#  (483.0, 0.0, 0.0, 0.0, 1.0),
#  (484.0, 0.0, 0.5, 0.0, 0.5),
#  (485.0, 0.0, 0.6, 0.4, 0.0),
#  (486.0, 0.0, 0.0, 1.0, 0.0),
#  (487.0, 0.33, 0.0, 0.33, 0.33),
#  (488.0, 0.0, 0.33, 0.67, 0.0),
#  (489.0, 0.0, 0.0, 1.0, 0.0),
#  (490.0, 0.2, 0.2, 0.6, 0.0),
#  (491.0, 0.0, 0.2, 0.8, 0.0),
#  (492.0, 1.0, 0.0, 0.0, 0.0),
#  (493.0, 1.0, 0.0, 0.0, 0.0),
#  (494.0, 0.25, 0.0, 0.5, 0.25),
#  (495.0, 0.5, 0.0, 0.5, 0.0),
#  (496.0, 1.0, 0.0, 0.0, 0.0),
#  (497.0, 0.0, 0.0, 1.0, 0.0),
#  (498.0, 0.0, 0.0, 1.0, 0.0),
#  (499.0, 0.0, 0.0, 1.0, 0.0),
#  (500.0, 0.0, 0.2, 0.8, 0.0),
#  (501.0, 1.0, 0.0, 0.0, 0.0),
#  (502.0, 0.0, 0.0, 1.0, 0.0),
#  (503.0, 0.0, 0.0, 1.0, 0.0),
#  (504.0, 0.0, 0.0, 1.0, 0.0),
#  (505.0, 0.0, 0.0, 1.0, 0.0),
#  (506.0, 0.0, 0.5, 0.25, 0.25),
#  (507.0, 0.0, 0.0, 0.75, 0.25),
#  (508.0, 0.0, 0.0, 0.5, 0.5),
#  (509.0, 0.0, 0.25, 0.75, 0.0),
#  (510.0, 0.0, 0.4, 0.6, 0.0),
#  (511.0, 0.0, 0.2, 0.8, 0.0),
#  (512.0, 0.0, 0.0, 0.67, 0.33),
#  (513.0, 0.25, 0.25, 0.25, 0.25),
#  (514.0, 0.0, 0.0, 1.0, 0.0),
#  (515.0, 0.0, 0.0, 1.0, 0.0),
#  (516.0, 0.33, 0.0, 0.67, 0.0),
#  (517.0, 0.0, 0.0, 0.67, 0.33),
#  (518.0, 0.0, 0.0, 1.0, 0.0),
#  (519.0, 0.0, 0.0, 1.0, 0.0),
#  (520.0, 0.5, 0.0, 0.5, 0.0),
#  (521.0, 0.5, 0.0, 0.5, 0.0),
#  (522.0, 0.0, 0.0, 1.0, 0.0),
#  (523.0, 0.0, 0.0, 1.0, 0.0),
#  (524.0, 0.0, 0.0, 1.0, 0.0),
#  (525.0, 0.0, 0.0, 1.0, 0.0),
#  (526.0, 1.0, 0.0, 0.0, 0.0),
#  (527.0, 0.0, 0.25, 0.75, 0.0),
#  (528.0, 0.0, 0.0, 1.0, 0.0),
#  (529.0, 0.0, 0.0, 0.8, 0.2),
#  (530.0, 0.0, 0.0, 1.0, 0.0),
#  (531.0, 0.0, 0.0, 1.0, 0.0),
#  (532.0, 0.5, 0.0, 0.5, 0.0),
#  (533.0, 0.33, 0.67, 0.0, 0.0),
#  (534.0, 0.0, 0.0, 1.0, 0.0),
#  (535.0, 0.0, 0.2, 0.8, 0.0),
#  (536.0, 0.0, 0.0, 0.0, 1.0),
#  (537.0, 0.0, 0.2, 0.6, 0.2),
#  (538.0, 0.0, 0.25, 0.5, 0.25),
#  (539.0, 0.0, 0.5, 0.5, 0.0),
#  (540.0, 0.33, 0.33, 0.33, 0.0),
#  (541.0, 0.2, 0.4, 0.4, 0.0),
#  (542.0, 0.0, 0.0, 1.0, 0.0),
#  (543.0, 0.0, 0.0, 1.0, 0.0),
#  (544.0, 0.0, 0.67, 0.33, 0.0),
#  (545.0, 0.0, 1.0, 0.0, 0.0),
#  (546.0, 0.4, 0.0, 0.6, 0.0),
#  (547.0, 0.0, 0.0, 1.0, 0.0),
#  (548.0, 0.5, 0.5, 0.0, 0.0),
#  (549.0, 0.6, 0.0, 0.4, 0.0),
#  (550.0, 0.2, 0.2, 0.6, 0.0),
#  (551.0, 0.33, 0.33, 0.33, 0.0),
#  (552.0, 0.0, 0.67, 0.33, 0.0),
#  (553.0, 0.5, 0.25, 0.0, 0.25),
#  (554.0, 0.0, 0.0, 1.0, 0.0),
#  (555.0, 0.0, 0.5, 0.0, 0.5),
#  (556.0, 0.0, 0.5, 0.5, 0.0),
#  (557.0, 0.5, 0.0, 0.0, 0.5),
#  (558.0, 0.2, 0.0, 0.8, 0.0),
#  (559.0, 0.0, 0.0, 1.0, 0.0),
#  (560.0, 0.0, 0.33, 0.67, 0.0),
#  (561.0, 0.0, 0.0, 1.0, 0.0),
#  (562.0, 0.25, 0.0, 0.75, 0.0),
#  (563.0, 0.2, 0.2, 0.6, 0.0),
#  (564.0, 0.0, 0.0, 1.0, 0.0),
#  (565.0, 0.0, 0.4, 0.6, 0.0),
#  (566.0, 0.25, 0.0, 0.5, 0.25),
#  (567.0, 0.0, 0.5, 0.25, 0.25),
#  (568.0, 0.0, 0.0, 1.0, 0.0),
#  (569.0, 0.0, 0.0, 1.0, 0.0),
#  (570.0, 0.0, 0.5, 0.5, 0.0),
#  (571.0, 0.0, 0.0, 1.0, 0.0),
#  (572.0, 0.0, 0.0, 1.0, 0.0),
#  (573.0, 0.0, 0.0, 1.0, 0.0),
#  (574.0, 0.75, 0.0, 0.25, 0.0),
#  (575.0, 0.4, 0.2, 0.4, 0.0),
#  (576.0, 0.0, 0.4, 0.6, 0.0),
#  (577.0, 0.0, 0.5, 0.5, 0.0),
#  (578.0, 0.0, 0.33, 0.67, 0.0),
#  (579.0, 0.0, 0.0, 1.0, 0.0),
#  (580.0, 0.0, 0.0, 1.0, 0.0),
#  (581.0, 0.0, 0.0, 1.0, 0.0),
#  (582.0, 0.25, 0.5, 0.25, 0.0),
#  (583.0, 0.0, 0.5, 0.5, 0.0),
#  (584.0, 0.0, 0.0, 1.0, 0.0),
#  (585.0, 0.5, 0.0, 0.0, 0.5),
#  (586.0, 0.2, 0.0, 0.6, 0.2),
#  (587.0, 0.0, 0.25, 0.5, 0.25),
#  (588.0, 0.33, 0.0, 0.33, 0.33),
#  (589.0, 0.25, 0.0, 0.75, 0.0),
#  (590.0, 0.25, 0.0, 0.75, 0.0),
#  (591.0, 0.0, 1.0, 0.0, 0.0),
#  (592.0, 0.0, 0.0, 1.0, 0.0),
#  (593.0, 0.0, 0.0, 1.0, 0.0),
#  (594.0, 0.5, 0.0, 0.5, 0.0),
#  (595.0, 0.2, 0.2, 0.6, 0.0),
#  (596.0, 0.0, 0.0, 0.5, 0.5),
#  (597.0, 0.33, 0.0, 0.67, 0.0),
#  (598.0, 0.25, 0.0, 0.75, 0.0),
#  (599.0, 0.0, 0.0, 1.0, 0.0),
#  (600.0, 0.0, 0.0, 1.0, 0.0),
#  (601.0, 1.0, 0.0, 0.0, 0.0),
#  (602.0, 0.25, 0.0, 0.75, 0.0),
#  (603.0, 0.0, 0.0, 1.0, 0.0),
#  (604.0, 0.0, 0.0, 1.0, 0.0),
#  (605.0, 0.2, 0.0, 0.6, 0.2),
#  (606.0, 0.0, 0.0, 0.0, 1.0),
#  (607.0, 0.0, 0.0, 1.0, 0.0),
#  (608.0, 0.33, 0.67, 0.0, 0.0),
#  (609.0, 0.25, 0.25, 0.0, 0.5),
#  (610.0, 0.0, 0.0, 1.0, 0.0),
#  (611.0, 1.0, 0.0, 0.0, 0.0),
#  (612.0, 0.0, 0.6, 0.2, 0.2),
#  (613.0, 0.5, 0.5, 0.0, 0.0),
#  (614.0, 0.5, 0.0, 0.5, 0.0),
#  (615.0, 0.0, 0.0, 0.5, 0.5),
#  (616.0, 0.25, 0.25, 0.5, 0.0),
#  (617.0, 0.5, 0.0, 0.5, 0.0),
#  (618.0, 1.0, 0.0, 0.0, 0.0),
#  (619.0, 0.0, 0.67, 0.33, 0.0),
#  (620.0, 0.33, 0.0, 0.0, 0.67),
#  (621.0, 0.0, 0.0, 1.0, 0.0),
#  (622.0, 0.67, 0.0, 0.0, 0.33),
#  (623.0, 0.0, 0.0, 1.0, 0.0),
#  (624.0, 0.0, 0.0, 1.0, 0.0),
#  (625.0, 0.0, 0.5, 0.5, 0.0),
#  (626.0, 0.0, 0.0, 1.0, 0.0),
#  (627.0, 0.0, 1.0, 0.0, 0.0),
#  (628.0, 0.0, 0.0, 0.5, 0.5),
#  (629.0, 0.0, 0.0, 0.75, 0.25),
#  (630.0, 0.0, 0.2, 0.8, 0.0),
#  (631.0, 0.0, 0.25, 0.75, 0.0),
#  (632.0, 0.0, 0.0, 0.8, 0.2),
#  (633.0, 0.0, 0.0, 1.0, 0.0),
#  (634.0, 0.0, 0.5, 0.5, 0.0),
#  (635.0, 0.0, 0.0, 1.0, 0.0),
#  (636.0, 0.0, 0.0, 0.5, 0.5),
#  (637.0, 0.0, 0.0, 1.0, 0.0),
#  (638.0, 0.0, 0.4, 0.4, 0.2),
#  (639.0, 0.0, 0.33, 0.67, 0.0),
#  (640.0, 0.0, 0.25, 0.75, 0.0),
#  (641.0, 0.2, 0.2, 0.6, 0.0),
#  (642.0, 0.0, 0.33, 0.67, 0.0),
#  (643.0, 0.0, 0.0, 0.5, 0.5),
#  (644.0, 0.33, 0.33, 0.33, 0.0),
#  (645.0, 0.0, 0.0, 1.0, 0.0),
#  (646.0, 0.0, 0.5, 0.0, 0.5),
#  (647.0, 0.0, 0.0, 1.0, 0.0),
#  (648.0, 0.0, 0.25, 0.25, 0.5),
#  (649.0, 0.25, 0.25, 0.5, 0.0),
#  (650.0, 0.0, 0.0, 1.0, 0.0),
#  (651.0, 0.0, 0.0, 0.5, 0.5),
#  (652.0, 0.0, 0.0, 1.0, 0.0),
#  (653.0, 0.0, 0.25, 0.5, 0.25),
#  (654.0, 0.25, 0.25, 0.5, 0.0),
#  (655.0, 0.0, 0.0, 1.0, 0.0),
#  (656.0, 0.0, 0.0, 1.0, 0.0),
#  (657.0, 0.0, 0.0, 1.0, 0.0),
#  (658.0, 0.0, 0.25, 0.5, 0.25),
#  (659.0, 0.0, 0.0, 1.0, 0.0),
#  (660.0, 0.2, 0.0, 0.6, 0.2),
#  (661.0, 0.0, 0.0, 1.0, 0.0),
#  (662.0, 0.0, 0.5, 0.5, 0.0),
#  (663.0, 0.0, 0.0, 0.5, 0.5),
#  (664.0, 0.5, 0.0, 0.5, 0.0),
#  (665.0, 0.0, 0.5, 0.5, 0.0),
#  (666.0, 0.0, 0.0, 1.0, 0.0),
#  (667.0, 0.25, 0.25, 0.5, 0.0),
#  (668.0, 0.6, 0.2, 0.2, 0.0),
#  (669.0, 0.0, 0.0, 1.0, 0.0),
#  (670.0, 0.0, 0.0, 1.0, 0.0),
#  (671.0, 0.2, 0.0, 0.6, 0.2),
#  (672.0, 0.0, 0.0, 1.0, 0.0),
#  (673.0, 0.5, 0.0, 0.5, 0.0),
#  (674.0, 0.5, 0.0, 0.5, 0.0),
#  (675.0, 0.0, 0.0, 0.5, 0.5),
#  (676.0, 0.0, 0.2, 0.6, 0.2),
#  (677.0, 0.0, 0.0, 1.0, 0.0),
#  (678.0, 0.0, 0.5, 0.5, 0.0),
#  (679.0, 0.0, 0.33, 0.67, 0.0),
#  (680.0, 0.5, 0.0, 0.5, 0.0),
#  (681.0, 0.0, 0.0, 0.6, 0.4),
#  (682.0, 1.0, 0.0, 0.0, 0.0),
#  (683.0, 0.0, 0.0, 1.0, 0.0),
#  (684.0, 0.0, 0.2, 0.8, 0.0),
#  (685.0, 0.33, 0.0, 0.67, 0.0),
#  (686.0, 0.0, 0.25, 0.5, 0.25),
#  (687.0, 0.0, 0.5, 0.5, 0.0),
#  (688.0, 1.0, 0.0, 0.0, 0.0),
#  (689.0, 1.0, 0.0, 0.0, 0.0),
#  (690.0, 0.0, 0.25, 0.5, 0.25),
#  (691.0, 0.4, 0.0, 0.6, 0.0),
#  (692.0, 0.0, 0.0, 1.0, 0.0),
#  (693.0, 0.0, 0.0, 0.5, 0.5),
#  (694.0, 0.0, 0.0, 1.0, 0.0),
#  (695.0, 0.25, 0.0, 0.5, 0.25),
#  (696.0, 0.2, 0.2, 0.4, 0.2),
#  (697.0, 0.0, 0.0, 1.0, 0.0),
#  (698.0, 0.33, 0.33, 0.33, 0.0),
#  (699.0, 0.5, 0.5, 0.0, 0.0),
#  (700.0, 0.25, 0.0, 0.75, 0.0),
#  (701.0, 0.33, 0.0, 0.67, 0.0),
#  (702.0, 0.0, 0.33, 0.67, 0.0),
#  (703.0, 0.0, 0.0, 1.0, 0.0),
#  (704.0, 0.0, 0.0, 0.75, 0.25),
#  (705.0, 0.2, 0.2, 0.6, 0.0),
#  (706.0, 0.0, 0.33, 0.67, 0.0),
#  (707.0, 0.0, 0.5, 0.5, 0.0),
#  (708.0, 0.33, 0.67, 0.0, 0.0),
#  (709.0, 0.0, 0.0, 1.0, 0.0),
#  (710.0, 0.0, 0.33, 0.67, 0.0),
#  (711.0, 0.0, 0.0, 1.0, 0.0),
#  (712.0, 1.0, 0.0, 0.0, 0.0),
#  (713.0, 0.2, 0.0, 0.6, 0.2),
#  (714.0, 0.25, 0.25, 0.25, 0.25),
#  (715.0, 0.2, 0.0, 0.8, 0.0),
#  (716.0, 0.0, 0.33, 0.67, 0.0),
#  (717.0, 0.0, 0.0, 0.67, 0.33),
#  (718.0, 0.0, 1.0, 0.0, 0.0),
#  (719.0, 0.0, 0.0, 1.0, 0.0),
#  (720.0, 0.0, 0.0, 1.0, 0.0),
#  (721.0, 0.0, 0.0, 1.0, 0.0),
#  (722.0, 0.0, 0.0, 1.0, 0.0),
#  (723.0, 0.0, 0.0, 0.75, 0.25),
#  (724.0, 0.0, 0.5, 0.5, 0.0),
#  (725.0, 0.2, 0.0, 0.8, 0.0),
#  (726.0, 1.0, 0.0, 0.0, 0.0),
#  (727.0, 0.2, 0.0, 0.6, 0.2),
#  (728.0, 0.2, 0.0, 0.8, 0.0),
#  (729.0, 0.0, 0.0, 1.0, 0.0),
#  (730.0, 0.0, 0.0, 0.67, 0.33),
#  (731.0, 0.0, 0.0, 1.0, 0.0),
#  (732.0, 0.33, 0.0, 0.67, 0.0),
#  (733.0, 0.2, 0.2, 0.6, 0.0),
#  (734.0, 0.0, 0.5, 0.5, 0.0),
#  (735.0, 0.0, 0.0, 0.5, 0.5),
#  (736.0, 0.0, 0.5, 0.5, 0.0),
#  (737.0, 0.2, 0.2, 0.6, 0.0),
#  (738.0, 1.0, 0.0, 0.0, 0.0),
#  (739.0, 0.33, 0.0, 0.33, 0.33),
#  (740.0, 0.33, 0.0, 0.67, 0.0),
#  (741.0, 0.33, 0.0, 0.67, 0.0),
#  (742.0, 0.0, 0.0, 0.5, 0.5),
#  (743.0, 0.0, 0.0, 0.5, 0.5),
#  (744.0, 0.0, 1.0, 0.0, 0.0),
#  (745.0, 0.0, 0.0, 1.0, 0.0),
#  (746.0, 0.2, 0.0, 0.4, 0.4),
#  (747.0, 0.5, 0.25, 0.25, 0.0),
#  (748.0, 0.0, 1.0, 0.0, 0.0),
#  (749.0, 0.0, 0.2, 0.6, 0.2),
#  (750.0, 0.5, 0.0, 0.5, 0.0),
#  (751.0, 0.0, 0.0, 1.0, 0.0),
#  (752.0, 0.0, 0.4, 0.4, 0.2),
#  (753.0, 0.0, 0.0, 0.5, 0.5),
#  (754.0, 0.0, 0.5, 0.5, 0.0),
#  (755.0, 0.0, 0.25, 0.5, 0.25),
#  (756.0, 1.0, 0.0, 0.0, 0.0),
#  (757.0, 0.2, 0.0, 0.6, 0.2),
#  (758.0, 0.5, 0.0, 0.5, 0.0),
#  (759.0, 0.0, 0.0, 0.6, 0.4),
#  (760.0, 0.5, 0.0, 0.0, 0.5),
#  (761.0, 0.0, 0.0, 1.0, 0.0),
#  (762.0, 0.0, 0.4, 0.6, 0.0),
#  (763.0, 0.0, 0.5, 0.5, 0.0),
#  (764.0, 0.0, 0.0, 1.0, 0.0),
#  (765.0, 0.33, 0.33, 0.33, 0.0),
#  (766.0, 0.5, 0.0, 0.0, 0.5),
#  (767.0, 0.0, 0.2, 0.6, 0.2),
#  (768.0, 0.5, 0.0, 0.5, 0.0),
#  (769.0, 0.0, 0.0, 1.0, 0.0),
#  (770.0, 0.5, 0.0, 0.5, 0.0),
#  (771.0, 0.33, 0.33, 0.33, 0.0),
#  (772.0, 0.0, 0.0, 1.0, 0.0),
#  (773.0, 0.0, 0.0, 1.0, 0.0),
#  (774.0, 0.0, 0.0, 1.0, 0.0),
#  (775.0, 0.0, 0.0, 1.0, 0.0),
#  (776.0, 0.0, 0.0, 0.67, 0.33),
#  (777.0, 0.25, 0.25, 0.25, 0.25),
#  (778.0, 0.0, 1.0, 0.0, 0.0),
#  (779.0, 0.0, 0.0, 1.0, 0.0),
#  (780.0, 0.0, 0.0, 1.0, 0.0),
#  (781.0, 0.2, 0.6, 0.2, 0.0),
#  (782.0, 0.33, 0.33, 0.0, 0.33),
#  (783.0, 0.0, 0.0, 1.0, 0.0),
#  (784.0, 0.0, 0.2, 0.4, 0.4),
#  (785.0, 0.0, 0.0, 1.0, 0.0),
#  (786.0, 0.0, 1.0, 0.0, 0.0),
#  (787.0, 0.0, 0.0, 1.0, 0.0),
#  (788.0, 0.0, 0.0, 1.0, 0.0),
#  (789.0, 0.25, 0.25, 0.5, 0.0),
#  (790.0, 0.0, 0.5, 0.5, 0.0),
#  (791.0, 0.0, 0.0, 1.0, 0.0),
#  (792.0, 0.5, 0.25, 0.25, 0.0),
#  (793.0, 0.0, 0.25, 0.5, 0.25),
#  (794.0, 0.0, 0.25, 0.75, 0.0),
#  (795.0, 0.0, 0.0, 1.0, 0.0),
#  (796.0, 0.5, 0.5, 0.0, 0.0),
#  (797.0, 0.0, 0.25, 0.75, 0.0),
#  (798.0, 0.0, 0.0, 0.75, 0.25),
#  (799.0, 0.0, 0.5, 0.5, 0.0),
#  (800.0, 0.5, 0.0, 0.0, 0.5),
#  (801.0, 0.2, 0.0, 0.8, 0.0),
#  (802.0, 1.0, 0.0, 0.0, 0.0),
#  (803.0, 0.2, 0.4, 0.4, 0.0),
#  (804.0, 0.33, 0.33, 0.33, 0.0),
#  (805.0, 0.0, 0.2, 0.8, 0.0),
#  (806.0, 0.0, 0.0, 0.75, 0.25),
#  (807.0, 0.33, 0.0, 0.67, 0.0),
#  (808.0, 0.0, 0.0, 1.0, 0.0),
#  (809.0, 0.0, 0.0, 1.0, 0.0),
#  (810.0, 0.33, 0.0, 0.33, 0.33),
#  (811.0, 0.6, 0.0, 0.2, 0.2),
#  (812.0, 0.5, 0.0, 0.5, 0.0),
#  (813.0, 0.0, 0.0, 1.0, 0.0),
#  (814.0, 0.0, 0.0, 1.0, 0.0),
#  (815.0, 0.0, 0.0, 1.0, 0.0),
#  (816.0, 0.0, 0.0, 1.0, 0.0),
#  (817.0, 0.0, 0.0, 1.0, 0.0),
#  (818.0, 0.0, 0.25, 0.5, 0.25),
#  (819.0, 0.2, 0.0, 0.8, 0.0),
#  (820.0, 0.0, 0.0, 0.5, 0.5),
#  (821.0, 0.0, 0.4, 0.6, 0.0),
#  (822.0, 0.0, 0.0, 1.0, 0.0),
#  (823.0, 0.0, 0.0, 1.0, 0.0),
#  (824.0, 0.0, 0.0, 1.0, 0.0),
#  (825.0, 0.0, 0.0, 1.0, 0.0),
#  (826.0, 1.0, 0.0, 0.0, 0.0),
#  (827.0, 0.0, 0.0, 1.0, 0.0),
#  (828.0, 0.0, 0.0, 1.0, 0.0),
#  (829.0, 0.0, 0.0, 1.0, 0.0),
#  (830.0, 0.0, 0.0, 0.6, 0.4),
#  (831.0, 0.0, 0.25, 0.25, 0.5),
#  (832.0, 0.25, 0.25, 0.5, 0.0),
#  (833.0, 0.0, 0.0, 1.0, 0.0),
#  (834.0, 0.0, 0.0, 1.0, 0.0),
#  (835.0, 0.2, 0.4, 0.4, 0.0),
#  (836.0, 0.0, 0.5, 0.0, 0.5),
#  (837.0, 0.0, 0.67, 0.33, 0.0),
#  (838.0, 0.2, 0.2, 0.4, 0.2),
#  (839.0, 0.0, 0.2, 0.8, 0.0),
#  (840.0, 0.0, 0.0, 0.75, 0.25),
#  (841.0, 0.0, 0.0, 1.0, 0.0),
#  (842.0, 0.0, 0.4, 0.6, 0.0),
#  (843.0, 0.0, 0.0, 1.0, 0.0),
#  (844.0, 0.33, 0.0, 0.67, 0.0),
#  (845.0, 0.0, 0.0, 0.75, 0.25),
#  (846.0, 0.0, 0.0, 1.0, 0.0),
#  (847.0, 0.25, 0.0, 0.5, 0.25),
#  (848.0, 0.0, 1.0, 0.0, 0.0),
#  (849.0, 0.0, 0.0, 0.5, 0.5),
#  (850.0, 0.0, 1.0, 0.0, 0.0),
#  (851.0, 0.0, 1.0, 0.0, 0.0),
#  (852.0, 0.0, 0.0, 1.0, 0.0),
#  (853.0, 0.25, 0.25, 0.5, 0.0),
#  (854.0, 0.0, 0.5, 0.5, 0.0),
#  (855.0, 0.0, 0.0, 1.0, 0.0),
#  (856.0, 0.0, 0.2, 0.6, 0.2),
#  (857.0, 0.0, 0.5, 0.5, 0.0),
#  (858.0, 0.33, 0.0, 0.67, 0.0),
#  (859.0, 0.0, 0.0, 1.0, 0.0),
#  (860.0, 0.0, 1.0, 0.0, 0.0),
#  (861.0, 0.2, 0.2, 0.2, 0.4),
#  (862.0, 0.0, 0.0, 0.8, 0.2),
#  (863.0, 0.0, 0.0, 1.0, 0.0),
#  (864.0, 0.6, 0.0, 0.4, 0.0),
#  (865.0, 0.0, 0.0, 0.5, 0.5),
#  (866.0, 0.25, 0.0, 0.75, 0.0),
#  (867.0, 0.2, 0.2, 0.6, 0.0),
#  (868.0, 0.0, 0.0, 1.0, 0.0),
#  (869.0, 0.0, 0.2, 0.6, 0.2),
#  (870.0, 0.2, 0.2, 0.6, 0.0),
#  (871.0, 0.0, 0.0, 1.0, 0.0),
#  (872.0, 0.4, 0.4, 0.2, 0.0),
#  (873.0, 1.0, 0.0, 0.0, 0.0),
#  (874.0, 0.0, 0.0, 0.6, 0.4),
#  (875.0, 0.5, 0.0, 0.5, 0.0),
#  (876.0, 0.0, 0.2, 0.6, 0.2),
#  (877.0, 0.0, 0.0, 0.5, 0.5),
#  (878.0, 0.0, 0.0, 0.0, 1.0),
#  (879.0, 0.5, 0.0, 0.5, 0.0),
#  (880.0, 0.0, 0.0, 1.0, 0.0),
#  (881.0, 0.0, 0.0, 0.75, 0.25),
#  (882.0, 0.4, 0.0, 0.6, 0.0),
#  (883.0, 0.4, 0.0, 0.6, 0.0),
#  (884.0, 0.0, 0.0, 1.0, 0.0),
#  (885.0, 1.0, 0.0, 0.0, 0.0),
#  (886.0, 1.0, 0.0, 0.0, 0.0),
#  (887.0, 0.0, 0.0, 1.0, 0.0),
#  (888.0, 0.0, 0.25, 0.75, 0.0),
#  (889.0, 0.2, 0.2, 0.4, 0.2),
#  (890.0, 0.0, 0.0, 0.5, 0.5),
#  (891.0, 0.25, 0.0, 0.75, 0.0),
#  (892.0, 0.0, 0.5, 0.0, 0.5),
#  (893.0, 0.0, 0.0, 1.0, 0.0),
#  (894.0, 0.0, 0.8, 0.0, 0.2),
#  (895.0, 0.0, 0.33, 0.67, 0.0),
#  (896.0, 0.0, 0.4, 0.6, 0.0),
#  (897.0, 0.25, 0.25, 0.5, 0.0),
#  (898.0, 0.0, 0.0, 0.8, 0.2),
#  (899.0, 0.33, 0.0, 0.67, 0.0),
#  (900.0, 0.0, 0.0, 1.0, 0.0),
#  (901.0, 0.25, 0.0, 0.75, 0.0),
#  (902.0, 0.0, 0.0, 1.0, 0.0),
#  (903.0, 0.0, 0.0, 1.0, 0.0),
#  (904.0, 0.0, 0.0, 1.0, 0.0),
#  (905.0, 0.0, 0.0, 0.0, 1.0),
#  (906.0, 0.0, 0.2, 0.4, 0.4),
#  (907.0, 0.0, 0.0, 1.0, 0.0),
#  (908.0, 0.0, 0.2, 0.6, 0.2),
#  (909.0, 0.25, 0.25, 0.25, 0.25),
#  (910.0, 1.0, 0.0, 0.0, 0.0),
#  (911.0, 0.0, 0.5, 0.5, 0.0),
#  (912.0, 0.0, 0.2, 0.6, 0.2),
#  (913.0, 0.67, 0.0, 0.33, 0.0),
#  (914.0, 0.0, 0.0, 1.0, 0.0),
#  (915.0, 0.25, 0.25, 0.5, 0.0),
#  (916.0, 0.0, 0.33, 0.67, 0.0),
#  (917.0, 0.5, 0.0, 0.0, 0.5),
#  (918.0, 0.5, 0.0, 0.5, 0.0),
#  (919.0, 0.0, 0.0, 0.67, 0.33),
#  (920.0, 0.25, 0.0, 0.75, 0.0),
#  (921.0, 0.0, 0.0, 0.8, 0.2),
#  (922.0, 0.0, 0.0, 0.67, 0.33),
#  (923.0, 0.25, 0.0, 0.5, 0.25),
#  (924.0, 0.33, 0.0, 0.67, 0.0),
#  (925.0, 0.0, 0.0, 1.0, 0.0),
#  (926.0, 0.0, 0.67, 0.33, 0.0),
#  (927.0, 0.33, 0.0, 0.67, 0.0),
#  (928.0, 0.33, 0.67, 0.0, 0.0),
#  (929.0, 0.0, 0.0, 1.0, 0.0),
#  (930.0, 0.0, 0.0, 0.67, 0.33),
#  (931.0, 0.0, 0.0, 1.0, 0.0),
#  (932.0, 0.0, 0.33, 0.67, 0.0),
#  (933.0, 0.2, 0.0, 0.8, 0.0),
#  (934.0, 0.25, 0.5, 0.25, 0.0),
#  (935.0, 0.0, 0.2, 0.8, 0.0),
#  (936.0, 1.0, 0.0, 0.0, 0.0),
#  (937.0, 0.0, 0.0, 1.0, 0.0),
#  (938.0, 0.0, 0.33, 0.67, 0.0),
#  (939.0, 1.0, 0.0, 0.0, 0.0),
#  (940.0, 0.5, 0.0, 0.25, 0.25),
#  (941.0, 0.0, 0.33, 0.67, 0.0),
#  (942.0, 0.0, 0.2, 0.6, 0.2),
#  (943.0, 0.0, 0.0, 1.0, 0.0),
#  (944.0, 1.0, 0.0, 0.0, 0.0),
#  (945.0, 0.0, 0.5, 0.25, 0.25),
#  (946.0, 0.4, 0.0, 0.6, 0.0),
#  (947.0, 0.0, 0.0, 0.8, 0.2),
#  (948.0, 0.0, 0.0, 1.0, 0.0),
#  (949.0, 0.0, 0.0, 0.5, 0.5),
#  (950.0, 0.5, 0.5, 0.0, 0.0),
#  (951.0, 0.0, 0.0, 1.0, 0.0),
#  (952.0, 0.5, 0.0, 0.5, 0.0),
#  (953.0, 0.0, 0.2, 0.8, 0.0),
#  (954.0, 0.0, 0.0, 1.0, 0.0),
#  (955.0, 0.0, 0.4, 0.4, 0.2),
#  (956.0, 0.0, 0.5, 0.5, 0.0),
#  (957.0, 0.5, 0.0, 0.25, 0.25),
#  (958.0, 0.0, 0.0, 1.0, 0.0),
#  (959.0, 0.2, 0.0, 0.8, 0.0),
#  (960.0, 0.0, 0.0, 1.0, 0.0),
#  (961.0, 0.33, 0.33, 0.0, 0.33),
#  (962.0, 0.2, 0.2, 0.4, 0.2),
#  (963.0, 0.0, 0.0, 1.0, 0.0),
#  (964.0, 0.0, 0.0, 1.0, 0.0),
#  (965.0, 0.0, 0.33, 0.0, 0.67),
#  (966.0, 0.0, 0.0, 1.0, 0.0),
#  (967.0, 0.0, 0.0, 1.0, 0.0),
#  (968.0, 0.4, 0.0, 0.4, 0.2),
#  (969.0, 0.5, 0.25, 0.0, 0.25),
#  (970.0, 0.0, 0.0, 1.0, 0.0),
#  (971.0, 1.0, 0.0, 0.0, 0.0),
#  (972.0, 0.0, 0.5, 0.5, 0.0),
#  (973.0, 0.2, 0.2, 0.6, 0.0),
#  (974.0, 0.0, 0.0, 1.0, 0.0),
#  (975.0, 0.0, 0.0, 0.5, 0.5),
#  (976.0, 0.0, 1.0, 0.0, 0.0),
#  (977.0, 0.0, 0.0, 1.0, 0.0),
#  (978.0, 0.0, 0.0, 0.75, 0.25),
#  (979.0, 0.0, 0.0, 0.0, 1.0),
#  (980.0, 0.0, 0.0, 1.0, 0.0),
#  (981.0, 0.33, 0.0, 0.67, 0.0),
#  (982.0, 0.25, 0.0, 0.75, 0.0),
#  (983.0, 0.0, 0.0, 0.8, 0.2),
#  (984.0, 0.0, 0.0, 1.0, 0.0),
#  (985.0, 0.0, 0.25, 0.75, 0.0),
#  (986.0, 0.0, 0.5, 0.0, 0.5),
#  (987.0, 0.0, 0.2, 0.8, 0.0),
#  (988.0, 0.0, 0.0, 1.0, 0.0),
#  (989.0, 0.0, 0.2, 0.6, 0.2),
#  (990.0, 0.0, 0.25, 0.75, 0.0),
#  (991.0, 0.0, 0.0, 0.5, 0.5),
#  (992.0, 0.0, 1.0, 0.0, 0.0),
#  (993.0, 0.2, 0.2, 0.4, 0.2),
#  (994.0, 0.0, 0.0, 1.0, 0.0),
#  (995.0, 0.33, 0.0, 0.67, 0.0),
#  (996.0, 0.0, 0.0, 1.0, 0.0),
#  (997.0, 0.0, 0.0, 1.0, 0.0),
#  (998.0, 0.0, 0.0, 0.67, 0.33)]
